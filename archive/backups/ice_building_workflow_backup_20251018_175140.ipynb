# %% [markdown]
# # ICE Building Workflow - Knowledge Graph Construction
#
# **Purpose**: Comprehensive data ingestion and knowledge graph building for investment intelligence
# **Architecture**: ICE Simplified (2,508 lines) with LightRAG integration
# **Input**: Financial data from multiple sources → **Output**: Searchable knowledge graph
#
# ## Workflow Overview
#
# 1. **Environment Setup** - Initialize ICE system and configure data sources
# 2. **Workflow Mode Selection** - Choose between initial build or incremental update
# 3. **Data Ingestion** - Fetch financial data from APIs and process documents
# 4. **Knowledge Graph Building** - Extract entities, relationships, and build LightRAG graph
# 5. **Storage & Validation** - Verify graph construction and monitor storage
# 6. **Metrics & Monitoring** - Track processing metrics and system health
#
# ---

# %% [markdown]
# ## 1. Environment Setup & System Initialization

# %%
# Setup and imports
import sys
import os
from pathlib import Path
from datetime import datetime, timedelta
import json

# Add project root to path
project_root = Path.cwd()
sys.path.insert(0, str(project_root))

# Configure environment
os.environ.setdefault('ICE_WORKING_DIR', './src/ice_lightrag/storage')

print(f"🚀 ICE Building Workflow")
print(f"📅 {datetime.now().strftime('%Y-%m-%d %H:%M')}")
print(f"📁 Working Directory: {project_root}")
# Out:
# 🚀 ICE Building Workflow
# 📅 2025-10-13 22:09
# 📁 Working Directory: /Users/royyeo/Library/CloudStorage/OneDrive-NationalUniversityofSingapore/Capstone Project

# %%
# Initialize ICE system
from updated_architectures.implementation.ice_simplified import create_ice_system

try:
    ice = create_ice_system()
    system_ready = ice.is_ready()
    print(f"✅ ICE System Initialized")
    print(f"🧠 LightRAG Status: {'Ready' if system_ready else 'Initializing'}")
    print(f"📊 Architecture: ICE Simplified (2,508 lines)")
    print(f"🔗 Components: Core + Ingester + QueryEngine")
except Exception as e:
    print(f"❌ Initialization Error: {e}")
    raise  # Let errors surface for proper debugging
# Out:
# INFO:ice_data_ingestion.ice_integration:ICE LightRAG system initialized successfully
# INFO:ice_data_ingestion.ice_integration:ICE LightRAG system initialized successfully
# INFO:updated_architectures.implementation.ice_simplified:ICE Core initializing with ICESystemManager orchestration
# INFO:src.ice_core.ice_system_manager:ICE System Manager initialized with working_dir: ice_lightrag/storage
# INFO:updated_architectures.implementation.ice_simplified:✅ ICESystemManager initialized successfully
# INFO:updated_architectures.implementation.ice_simplified:Data Ingester initialized with 4 API services
# INFO:updated_architectures.implementation.ice_simplified:Query Engine initialized
# INFO:updated_architectures.implementation.ice_simplified:✅ ICE Simplified system initialized successfully
# INFO:src.ice_core.ice_system_manager:LightRAG wrapper created successfully (lazy initialization mode)
# INFO:src.ice_core.ice_system_manager:Exa MCP connector initialized successfully
# INFO:src.ice_core.ice_graph_builder:ICE Graph Builder initialized
# INFO:src.ice_core.ice_graph_builder:LightRAG instance updated in Graph Builder
# INFO:src.ice_core.ice_system_manager:Graph Builder initialized successfully
# INFO:src.ice_core.ice_query_processor:ICE Query Processor initialized
# INFO:src.ice_core.ice_system_manager:Query Processor initialized successfully
# INFO:updated_architectures.implementation.ice_simplified:System health: ready=True
# INFO:updated_architectures.implementation.ice_simplified:Components: {'lightrag': True, 'exa_connector': True, 'graph_builder': True, 'query_processor': True, 'data_manager': False}
# INFO:updated_architectures.implementation.ice_simplified:✅ ICE system created and ready for operations
# ✅ LightRAG successfully imported!
# ✅ ICE System Initialized
# 🧠 LightRAG Status: Ready
# 📊 Architecture: ICE Simplified (2,508 lines)
# 🔗 Components: Core + Ingester + QueryEngine

# %%
# Verify storage architecture and components
print(f"📦 LightRAG Storage Architecture Verification")
print(f"━" * 40)

if not (ice and ice.core.is_ready()):
    raise RuntimeError("ICE system not ready - cannot verify storage")

# Get storage statistics using new method
storage_stats = ice.core.get_storage_stats()

print(f"LightRAG Storage Components:")
for component_name, component_info in storage_stats['components'].items():
    status = "✅ Initialized" if component_info['exists'] else "⚠️ Not created yet"
    size_mb = component_info['size_bytes'] / (1024 * 1024) if component_info['size_bytes'] > 0 else 0
    print(f"  {component_name}: {status}")
    print(f"    Purpose: {component_info['description']}")
    print(f"    File: {component_info['file']}")
    if size_mb > 0:
        print(f"    Size: {size_mb:.2f} MB")

print(f"\n📁 Working Directory: {storage_stats['working_dir']}")
print(f"🗄️ Storage Backend: File-based (development mode)")
print(f"💾 Total Storage: {storage_stats['total_storage_bytes'] / (1024 * 1024):.2f} MB")
# Out:
# 📦 LightRAG Storage Architecture Verification
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# LightRAG Storage Components:
#   chunks_vdb: ⚠️ Not created yet
#     Purpose: Vector database for document chunks
#     File: vdb_chunks.json
#   entities_vdb: ⚠️ Not created yet
#     Purpose: Vector database for extracted entities
#     File: vdb_entities.json
#   relationships_vdb: ⚠️ Not created yet
#     Purpose: Vector database for entity relationships
#     File: vdb_relationships.json
#   graph: ⚠️ Not created yet
#     Purpose: NetworkX graph structure
#     File: graph_chunk_entity_relation.graphml
#
# 📁 Working Directory: ice_lightrag/storage
# 🗄️ Storage Backend: File-based (development mode)
# 💾 Total Storage: 0.00 MB

# %%
# Data sources configuration status
if not (ice and hasattr(ice, 'ingester')):
    raise RuntimeError("Data ingester not initialized")

available_services = ice.ingester.available_services
print(f"\n📡 Data Sources Available: {len(available_services)}")
for service in available_services:
    print(f"  ✅ {service}")

if not available_services:
    print(f"  ⚠️ No APIs configured - will use sample data")
    print(f"  💡 Set NEWSAPI_ORG_API_KEY for real news")
    print(f"  💡 Set ALPHA_VANTAGE_API_KEY for financial data")

# Validate OpenAI for LightRAG
openai_configured = bool(os.getenv('OPENAI_API_KEY'))
print(f"\n🔑 OpenAI API: {'✅ Configured' if openai_configured else '❌ Required for full functionality'}")
# Out:
# 📡 Data Sources Available: 4
#   ✅ alpha_vantage
#   ✅ newsapi
#   ✅ polygon
#   ✅ finnhub
#
# 🔑 OpenAI API: ✅ Configured

# %% [markdown]
# ## 2. Workflow Mode Selection & Configuration

# %% [markdown]
# ### 🔧 Model Provider Configuration
#
# ICE supports **OpenAI** (paid) or **Ollama** (free local) for LLM and embeddings:
#
# #### Option 1: OpenAI (Default - No setup required)
# ```bash
# export OPENAI_API_KEY="sk-..."
# ```
# - **Cost**: ~$5/month for typical usage
# - **Quality**: Highest accuracy for entity extraction and reasoning
# - **Setup**: Just set API key
#
# #### Option 2: Ollama (Free Local - Requires setup)
# ```bash
# # Set provider
# export LLM_PROVIDER="ollama"
#
# # One-time setup:
# ollama serve                      # Start Ollama service
# ollama pull qwen3:30b-32k        # Pull LLM model (32k context required)
# ollama pull nomic-embed-text      # Pull embedding model
# ```
# - **Cost**: $0/month (completely free)
# - **Quality**: Good for most investment analysis tasks
# - **Setup**: Requires local Ollama installation and model download
#
# #### Option 3: Hybrid (Recommended for cost-conscious users)
# ```bash
# export LLM_PROVIDER="ollama"           # Use Ollama for LLM
# export EMBEDDING_PROVIDER="openai"     # Use OpenAI for embeddings
# export OPENAI_API_KEY="sk-..."
# ```
# - **Cost**: ~$2/month (embeddings only)
# - **Quality**: Balanced - free LLM with high-quality embeddings
#
# **Current configuration will be logged when you run the next cell.**

# %%
# ### Provider Switching - Uncomment ONE option below, then restart kernel

#############################################################################
#                              Model Selection                              #
#############################################################################

### Option 1: OpenAI ($5/mo, highest quality)
import os; os.environ['LLM_PROVIDER'] = 'openai'
print("✅ Switched to OpenAI")

# ###Option 2: Hybrid ($2/mo, 60% savings, recommended)
# import os; os.environ['LLM_PROVIDER'] = 'ollama'; os.environ['EMBEDDING_PROVIDER'] = 'openai'
# print("✅ Switched to Hybrid")

# ### Option 3: Full Ollama ($0/mo, faster model)
# import os; os.environ['LLM_PROVIDER'] = 'ollama'; os.environ['EMBEDDING_PROVIDER'] = 'ollama'; 
# # os.environ['LLM_MODEL'] = 'llama3.1:8b'
# os.environ['LLM_MODEL'] = 'qwen3:8b'
# # os.environ['LLM_MODEL'] = 'qwen3:14b'
# # os.environ['LLM_MODEL'] = 'qwen3:30b-32k'
# print("✅ Switched to Full Ollama Model.")
# Out:
# ✅ Switched to OpenAI

# %% [markdown]
# ### 🗑️ Graph Management (Optional)
#
# **When to clear the graph:**
# - ✅ Switching to Full Ollama (1536-dim → 768-dim embeddings)
# - ✅ Graph corrupted or very old (>30 days without updates)
# - ✅ Testing fresh graph builds from scratch
#
# **When NOT to clear:**
# - ❌ Just switching LLM provider (OpenAI ↔ Hybrid use same embeddings)
# - ❌ Adding new documents (incremental updates work fine)
# - ❌ Changing query modes (local, hybrid, etc.)
#
# **How to clear:**
# Run the code cell below (uncomment lines to activate)

# %%
##########################################################
#                    Check graph info                    #
##########################################################
from updated_architectures.implementation.ice_simplified import create_ice_system
ice = create_ice_system()


##########################################################
from pathlib import Path
import shutil

def check_storage(storage_path):
    """Check and display storage file inventory"""
    files = ['vdb_entities.json', 'vdb_relationships.json', 'vdb_chunks.json', 'graph_chunk_entity_relation.graphml']
    total_size = 0
    for fname in files:
        fpath = storage_path / fname
        if fpath.exists():
            size_mb = fpath.stat().st_size / (1024 * 1024)
            print(f"  ✅ {fname}: {size_mb:.2f} MB")
            total_size += size_mb
        else:
            print(f"  ⚠️  {fname}: not found")
    print(f"  💾 Total: {total_size:.2f} MB")

# Use actual config path instead of hardcoded path to avoid path mismatches
storage_path = Path(ice.config.working_dir)

check_storage(storage_path)

#####################################################################
ice.core.get_graph_stats()

##########################################################
#              Graph Health Metrics (P0)                 #
##########################################################

def check_graph_health(storage_path):
    """Check critical graph health metrics (P0 only)"""
    import json
    from pathlib import Path
    
    TICKERS = {'NVDA', 'TSMC', 'AMD', 'ASML'}  # Known portfolio tickers
    
    result = {
        'tickers_covered': set(),
        'total_entities': 0,
        'total_relationships': 0,
        'buy_signals': 0,
        'sell_signals': 0,
        'price_targets': 0
    }
    
    # Parse entities
    entities_file = Path(storage_path) / 'vdb_entities.json'
    if entities_file.exists():
        data = json.loads(entities_file.read_text())
        result['total_entities'] = len(data.get('data', []))
        
        for entity in data.get('data', []):
            text = f"{entity.get('entity_name', '')} {entity.get('content', '')}".upper()
            
            # Detect tickers
            for ticker in TICKERS:
                if ticker in text:
                    result['tickers_covered'].add(ticker)
            
            # Detect signals
            if 'BUY' in text:
                result['buy_signals'] += 1
            if 'SELL' in text:
                result['sell_signals'] += 1
            if 'PRICE TARGET' in text or 'PRICE_TARGET' in text:
                result['price_targets'] += 1
    
    # Parse relationships
    rels_file = Path(storage_path) / 'vdb_relationships.json'
    if rels_file.exists():
        data = json.loads(rels_file.read_text())
        result['total_relationships'] = len(data.get('data', []))
    
    result['tickers_covered'] = sorted(list(result['tickers_covered']))
    return result

# Run health check
health = check_graph_health(storage_path)

# Display results
print("\n🧬 Graph Health Metrics:")
print(f"  📊 Content Coverage:")
print(f"    Tickers: {', '.join(health['tickers_covered']) if health['tickers_covered'] else 'None'} ({len(health['tickers_covered'])}/4 portfolio holdings)")

print(f"\n  🕸️ Graph Structure:")
print(f"    Total entities: {health['total_entities']:,}")
print(f"    Total relationships: {health['total_relationships']:,}")
if health['total_entities'] > 0:
    avg_conn = health['total_relationships'] / health['total_entities']
    print(f"    Avg connections: {avg_conn:.2f}")

print(f"\n  💼 Investment Signals:")
print(f"    BUY signals: {health['buy_signals']}")
print(f"    SELL signals: {health['sell_signals']}")
print(f"    Price targets: {health['price_targets']}")
# Out:
# INFO:updated_architectures.implementation.ice_simplified:ICE Core initializing with ICESystemManager orchestration
# INFO:src.ice_core.ice_system_manager:ICE System Manager initialized with working_dir: ice_lightrag/storage
# INFO:updated_architectures.implementation.ice_simplified:✅ ICESystemManager initialized successfully
# INFO:updated_architectures.implementation.ice_simplified:Data Ingester initialized with 4 API services
# INFO:updated_architectures.implementation.ice_simplified:Query Engine initialized
# INFO:updated_architectures.implementation.ice_simplified:✅ ICE Simplified system initialized successfully
# INFO:src.ice_core.ice_system_manager:LightRAG wrapper created successfully (lazy initialization mode)
# INFO:src.ice_core.ice_system_manager:Exa MCP connector initialized successfully
# INFO:src.ice_core.ice_graph_builder:ICE Graph Builder initialized
# INFO:src.ice_core.ice_graph_builder:LightRAG instance updated in Graph Builder
# INFO:src.ice_core.ice_system_manager:Graph Builder initialized successfully
# INFO:src.ice_core.ice_query_processor:ICE Query Processor initialized
# INFO:src.ice_core.ice_system_manager:Query Processor initialized successfully
# INFO:updated_architectures.implementation.ice_simplified:System health: ready=True
# INFO:updated_architectures.implementation.ice_simplified:Components: {'lightrag': True, 'exa_connector': True, 'graph_builder': True, 'query_processor': True, 'data_manager': False}
# INFO:updated_architectures.implementation.ice_simplified:✅ ICE system created and ready for operations
#   ✅ vdb_entities.json: 4.40 MB
#   ✅ vdb_relationships.json: 4.01 MB
#   ✅ vdb_chunks.json: 0.72 MB
#   ✅ graph_chunk_entity_relation.graphml: 0.32 MB
#   💾 Total: 9.46 MB
#
# 🧬 Graph Health Metrics:
#   📊 Content Coverage:
#     Tickers: NVDA (1/4 portfolio holdings)
#
#   🕸️ Graph Structure:
#     Total entities: 368
#     Total relationships: 337
#     Avg connections: 0.92
#
#   💼 Investment Signals:
#     BUY signals: 9
#     SELL signals: 1
#     Price targets: 0

# %% [markdown]
# ## 🧪 Test: Hybrid Entity Categorization with Qwen2.5-3B
#
# **Purpose**: Compare categorization accuracy between keyword-only and hybrid (keyword+LLM) approaches
#
# **What this tests**:
# - Baseline: Fast keyword pattern matching (~1ms per entity)
# - Enhanced: Confidence scoring to identify ambiguous cases
# - Hybrid: LLM fallback for low-confidence entities (~40ms per entity)
#
# **Prerequisites**:
# - ✅ Ollama installed with qwen2.5:3b model (optional - degrades gracefully)
# - ✅ LightRAG graph built (previous cells completed)
#
# **Expected runtime**: ~0.5 seconds for 12 sample entities (hybrid mode)
#
# **Configuration**: `src/ice_lightrag/graph_categorization.py` - Change `CATEGORIZATION_MODE` to enable hybrid by default

# %%
# Purpose: Test hybrid entity categorization with configurable sampling and model selection
# Location: ice_building_workflow.ipynb Cell 12 (after Cell 10)
# Dependencies: graph_categorization.py, entity_categories.py, LightRAG storage

import json
import time
import sys
import random
import requests
from pathlib import Path
from collections import Counter

# Force reload of graph_categorization module to pick up new functions
import importlib
if 'src.ice_lightrag.graph_categorization' in sys.modules:
    importlib.reload(sys.modules['src.ice_lightrag.graph_categorization'])

# ===== CONFIGURATION: User-editable settings =====
RANDOM_SEED = 42  # Set to None for different entities each run, or keep 42 for reproducible testing
OLLAMA_MODEL_OVERRIDE = 'qwen2.5:3b'  # Change to use different model (e.g., 'llama3.1:8b', 'qwen3:8b')

# ===== SETUP: Imports with error handling =====
print("=" * 70)
print("🧪 Entity Categorization Test (4 Modes)")
print("=" * 70)

# Ensure src is in path for notebook context
project_root = Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

try:
    from src.ice_lightrag.graph_categorization import (
        categorize_entity,
        categorize_entity_with_confidence,
        categorize_entity_hybrid,
        categorize_entity_llm_only  # NEW: Pure LLM mode
    )
    from src.ice_lightrag.entity_categories import CATEGORY_DISPLAY_ORDER
    print("✅ Categorization functions imported successfully")
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("   → Ensure previous cells completed successfully")
    print("   → Check that src/ice_lightrag/graph_categorization.py exists\n")
    raise

# Patch module constant for Ollama model selection
import src.ice_lightrag.graph_categorization as graph_cat_module
graph_cat_module.OLLAMA_MODEL = OLLAMA_MODEL_OVERRIDE
print(f"🔧 Ollama model configured: {OLLAMA_MODEL_OVERRIDE}\n")

# ===== HEALTH CHECK: Ollama service availability =====
def check_ollama_service():
    """Check if Ollama service is running and configured model is available"""
    try:
        response = requests.get("http://localhost:11434/api/tags", timeout=2)
        if response.status_code == 200:
            models = response.json().get('models', [])
            # Use exact match to avoid accepting wrong model versions
            model_available = any(m.get('name', '') == OLLAMA_MODEL_OVERRIDE for m in models)
            return True, model_available
        return False, False
    except requests.RequestException:
        return False, False
    except (KeyError, json.JSONDecodeError):
        return True, False

ollama_running, model_available = check_ollama_service()
if ollama_running and model_available:
    print(f"✅ Ollama service running with {OLLAMA_MODEL_OVERRIDE} model")
elif ollama_running:
    print(f"⚠️  Ollama running but {OLLAMA_MODEL_OVERRIDE} not found")
    print(f"   → Install: ollama pull {OLLAMA_MODEL_OVERRIDE}")
else:
    print("⚠️  Ollama not running - TEST 3 & 4 will be skipped")
    print("   → Start Ollama: brew services start ollama (macOS)\n")

# ===== DATA LOADING: Entities with validation =====
storage_path = Path(ice.config.working_dir) / "vdb_entities.json"

if not storage_path.exists():
    print(f"❌ Storage file not found: {storage_path}")
    print("   → Run previous cells to build the knowledge graph first\n")
    raise FileNotFoundError(f"LightRAG storage not found at {storage_path}")

with open(storage_path) as f:
    entities_data = json.load(f)

if not isinstance(entities_data, dict) or 'data' not in entities_data:
    print(f"❌ Invalid storage format (expected dict with 'data' key)")
    raise ValueError("Invalid LightRAG storage format - expected {'data': [...]}")

entities_list = entities_data.get('data', [])
if not isinstance(entities_list, list) or len(entities_list) == 0:
    print(f"❌ No entities found in storage")
    raise ValueError("No entities found in LightRAG storage")

print(f"✅ Loaded {len(entities_list)} entities from knowledge graph")

# Configurable random sampling
if RANDOM_SEED is not None:
    random.seed(RANDOM_SEED)
    sampling_mode = f"Reproducible (seed={RANDOM_SEED}, same entities each run)"
else:
    sampling_mode = "Random (different entities each run)"

test_entities = random.sample(entities_list, min(12, len(entities_list)))
print(f"   Sampling mode: {sampling_mode}")
print(f"   Testing with {len(test_entities)} entities")
print(f"   💡 To change: Set RANDOM_SEED = None (line 17) or OLLAMA_MODEL_OVERRIDE (line 18)\n")

# ===== HELPER: Compact result display =====
def display_results(results, title, show_confidence=False, show_llm=False):
    """Display categorization results in compact format"""
    print(f"\n{title}")
    print("-" * 70)

    for i, (name, category, confidence, used_llm) in enumerate(results, 1):
        display_name = name[:40] + "..." if len(name) > 40 else name

        if show_llm and used_llm:
            indicator = "🤖"
        else:
            indicator = "⚡"

        if show_confidence:
            print(f"{i:2d}. {indicator} {display_name:43s} → {category:20s} (conf: {confidence:.2f})")
        else:
            print(f"{i:2d}. {display_name:45s} → {category}")

    category_counts = Counter(cat for _, cat, _, _ in results)
    print(f"\n📊 Distribution: {dict(category_counts)}")

# ===== TEST 1: Keyword-Only Baseline =====
print("\n" + "=" * 70)
print("TEST 1: Keyword-Only Categorization (Baseline)")
print("=" * 70)

start_time = time.time()
keyword_results = []

for entity in test_entities:
    name = entity.get('entity_name', '')
    content = entity.get('content', '')
    category = categorize_entity(name, content)
    keyword_results.append((name, category, 1.0, False))

elapsed = time.time() - start_time
display_results(keyword_results, "Results (Keyword Matching):", show_confidence=False)
print(f"\n⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_entities):.1f}ms per entity)")

# ===== TEST 2: Confidence Scoring Analysis =====
print("\n" + "=" * 70)
print("TEST 2: Keyword + Confidence Scoring")
print("=" * 70)

start_time = time.time()
confidence_results = []

for entity in test_entities:
    name = entity.get('entity_name', '')
    content = entity.get('content', '')
    category, confidence = categorize_entity_with_confidence(name, content)
    confidence_results.append((name, category, confidence, False))

elapsed = time.time() - start_time
display_results(confidence_results, "Results (with confidence scores):", show_confidence=True)

low_confidence = [(n, c, conf) for n, c, conf, _ in confidence_results if conf < 0.70]
if low_confidence:
    print(f"\n🔍 Ambiguous entities (confidence < 0.70): {len(low_confidence)}")
    for name, cat, conf in low_confidence:
        print(f"   - {name[:50]:50s} → {cat:20s} (conf: {conf:.2f})")
else:
    print(f"\n✅ All entities have high confidence (≥0.70) - no LLM fallback needed")

print(f"\n⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_entities):.1f}ms per entity)")

# ===== TEST 3: Hybrid Mode (if Ollama available) =====
if ollama_running and model_available:
    print("\n" + "=" * 70)
    print("TEST 3: Hybrid Categorization (Keyword + LLM Fallback)")
    print("=" * 70)
    print("⏱️  Note: LLM calls may take 5-10 seconds total...\n")

    start_time = time.time()
    hybrid_results = []
    llm_call_count = 0

    for entity in test_entities:
        name = entity.get('entity_name', '')
        content = entity.get('content', '')

        keyword_cat, keyword_conf = categorize_entity_with_confidence(name, content)

        if keyword_conf >= 0.70:
            category, confidence = keyword_cat, keyword_conf
            used_llm = False
        else:
            category, confidence = categorize_entity_hybrid(name, content, confidence_threshold=0.70)
            used_llm = (confidence == 0.90)
            if used_llm:
                llm_call_count += 1

        hybrid_results.append((name, category, confidence, used_llm))

    elapsed = time.time() - start_time
    display_results(hybrid_results, "Results (Hybrid mode - keyword + LLM):", show_confidence=True, show_llm=True)

    print(f"\n🤖 LLM calls: {llm_call_count}/{len(test_entities)} ({100*llm_call_count/len(test_entities):.1f}%)")
    print(f"⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_entities):.1f}ms per entity)")

    # ===== COMPARISON SUMMARY =====
    print("\n" + "=" * 70)
    print("📊 COMPARISON SUMMARY (Keyword vs Hybrid)")
    print("=" * 70)

    changes = 0
    for i in range(len(test_entities)):
        if keyword_results[i][1] != hybrid_results[i][1]:
            changes += 1

    print(f"Entities recategorized by LLM: {changes}/{len(test_entities)} ({100*changes/len(test_entities):.1f}%)")

    if changes > 0:
        print("\nRecategorization details:")
        for i in range(len(test_entities)):
            kw_cat = keyword_results[i][1]
            hyb_cat = hybrid_results[i][1]
            if kw_cat != hyb_cat:
                name = test_entities[i].get('entity_name', '')[:50]
                print(f"   - {name:50s}: {kw_cat:20s} → {hyb_cat}")

    print(f"\n✅ Hybrid categorization complete!")

else:
    print("\n" + "=" * 70)
    print("⚠️  TEST 3 SKIPPED: Ollama not available")
    print("=" * 70)
    print("To enable hybrid mode:")
    print("   1. Install Ollama: https://ollama.com")
    print(f"   2. Pull model: ollama pull {OLLAMA_MODEL_OVERRIDE}")
    print("   3. Start service: brew services start ollama (macOS)")
    print("   4. Re-run this cell")

# ===== TEST 4: Pure LLM Mode (NEW) =====
if ollama_running and model_available:
    print("\n" + "=" * 70)
    print("TEST 4: Pure LLM Categorization (All entities)")
    print("=" * 70)
    print("⏱️  Note: This will call LLM for ALL entities (may take 30-60 seconds)...\n")

    start_time = time.time()
    llm_results = []

    for entity in test_entities:
        name = entity.get('entity_name', '')
        content = entity.get('content', '')
        category, confidence = categorize_entity_llm_only(name, content)
        llm_results.append((name, category, confidence, True))

    elapsed = time.time() - start_time
    display_results(llm_results, "Results (Pure LLM mode):", show_confidence=True, show_llm=True)

    print(f"\n🤖 LLM calls: {len(test_entities)}/{len(test_entities)} (100%)")
    print(f"⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_entities):.1f}ms per entity)")

    # Compare keyword vs pure LLM
    llm_changes = sum(1 for i in range(len(test_entities)) if keyword_results[i][1] != llm_results[i][1])
    
    print("\n" + "=" * 70)
    print("📊 COMPARISON SUMMARY (Keyword vs Pure LLM)")
    print("=" * 70)
    print(f"Entities recategorized by pure LLM: {llm_changes}/{len(test_entities)} ({100*llm_changes/len(test_entities):.1f}%)")
    
    if llm_changes > 0:
        print("\nRecategorization details:")
        for i in range(len(test_entities)):
            kw_cat = keyword_results[i][1]
            llm_cat = llm_results[i][1]
            if kw_cat != llm_cat:
                name = test_entities[i].get('entity_name', '')[:50]
                print(f"   - {name:50s}: {kw_cat:20s} → {llm_cat}")

    print(f"\n✅ Pure LLM categorization complete!")

else:
    print("\n" + "=" * 70)
    print("⚠️  TEST 4 SKIPPED: Ollama not available")
    print("=" * 70)
    print("To enable pure LLM mode:")
    print("   1. Install Ollama: https://ollama.com")
    print(f"   2. Pull model: ollama pull {OLLAMA_MODEL_OVERRIDE}")
    print("   3. Start service: brew services start ollama (macOS)")
    print("   4. Re-run this cell")

print("\n" + "=" * 70)
print("🎯 TESTING COMPLETE - 4 Categorization Modes Evaluated")
print("=" * 70)
# Out:
# ======================================================================
# 🧪 Entity Categorization Test (4 Modes)
# ======================================================================
# ✅ Categorization functions imported successfully
# 🔧 Ollama model configured: qwen2.5:3b
#
# ✅ Ollama service running with qwen2.5:3b model
# ✅ Loaded 368 entities from knowledge graph
#    Sampling mode: Reproducible (seed=42, same entities each run)
#    Testing with 12 entities
#    💡 To change: Set RANDOM_SEED = None (line 17) or OLLAMA_MODEL_OVERRIDE (line 18)
#
#
# ======================================================================
# TEST 1: Keyword-Only Categorization (Baseline)
# ======================================================================
#
# Results (Keyword Matching):
# ----------------------------------------------------------------------
#  1. Exxon Mobil Corporation                       → Company
#  2. September 13, 2025                            → Other
#  3. iPhone                                        → Company
#  4. Ritholtz Wealth Management                    → Other
#  5. JNJ                                           → Company
#  6. Financial Historical                          → Technology/Product
#  7. Chicago                                       → Other
#  8. 2025-09-18                                    → Company
#  9. San Ramon                                     → Company
# 10. Zach Cregger                                  → Other
# 11. AAPL                                          → Company
# 12. San Francisco                                 → Other
#
# 📊 Distribution: {'Company': 6, 'Other': 5, 'Technology/Product': 1}
#
# ⏱️  Time: 0.4ms (0.0ms per entity)
#
# ======================================================================
# TEST 2: Keyword + Confidence Scoring
# ======================================================================
#
# Results (with confidence scores):
# ----------------------------------------------------------------------
#  1. ⚡ Exxon Mobil Corporation                     → Company              (conf: 0.95)
#  2. ⚡ September 13, 2025                          → Other                (conf: 0.50)
#  3. ⚡ iPhone                                      → Company              (conf: 0.85)
#  4. ⚡ Ritholtz Wealth Management                  → Other                (conf: 0.50)
#  5. ⚡ JNJ                                         → Company              (conf: 0.85)
#  6. ⚡ Financial Historical                        → Technology/Product   (conf: 0.75)
#  7. ⚡ Chicago                                     → Other                (conf: 0.50)
#  8. ⚡ 2025-09-18                                  → Company              (conf: 0.85)
#  9. ⚡ San Ramon                                   → Company              (conf: 0.85)
# 10. ⚡ Zach Cregger                                → Other                (conf: 0.50)
# 11. ⚡ AAPL                                        → Company              (conf: 0.85)
# 12. ⚡ San Francisco                               → Other                (conf: 0.50)
#
# 📊 Distribution: {'Company': 6, 'Other': 5, 'Technology/Product': 1}
#
# 🔍 Ambiguous entities (confidence < 0.70): 5
#    - September 13, 2025                                 → Other                (conf: 0.50)
#    - Ritholtz Wealth Management                         → Other                (conf: 0.50)
#    - Chicago                                            → Other                (conf: 0.50)
#    - Zach Cregger                                       → Other                (conf: 0.50)
#    - San Francisco                                      → Other                (conf: 0.50)
#
# ⏱️  Time: 0.3ms (0.0ms per entity)
#
# ======================================================================
# TEST 3: Hybrid Categorization (Keyword + LLM Fallback)
# ======================================================================
# ⏱️  Note: LLM calls may take 5-10 seconds total...
#
#
# Results (Hybrid mode - keyword + LLM):
# ----------------------------------------------------------------------
#  1. ⚡ Exxon Mobil Corporation                     → Company              (conf: 0.95)
#  2. 🤖 September 13, 2025                          → Media/Source         (conf: 0.90)
#  3. ⚡ iPhone                                      → Company              (conf: 0.85)
#  4. 🤖 Ritholtz Wealth Management                  → Company              (conf: 0.90)
#  5. ⚡ JNJ                                         → Company              (conf: 0.85)
#  6. ⚡ Financial Historical                        → Technology/Product   (conf: 0.75)
#  7. 🤖 Chicago                                     → Media/Source         (conf: 0.90)
#  8. ⚡ 2025-09-18                                  → Company              (conf: 0.85)
#  9. ⚡ San Ramon                                   → Company              (conf: 0.85)
# 10. 🤖 Zach Cregger                                → Media/Source         (conf: 0.90)
# 11. ⚡ AAPL                                        → Company              (conf: 0.85)
# 12. 🤖 San Francisco                               → Geographic           (conf: 0.90)
#
# 📊 Distribution: {'Company': 7, 'Media/Source': 3, 'Technology/Product': 1, 'Geographic': 1}
#
# 🤖 LLM calls: 5/12 (41.7%)
# ⏱️  Time: 2142.9ms (178.6ms per entity)
#
# ======================================================================
# 📊 COMPARISON SUMMARY (Keyword vs Hybrid)
# ======================================================================
# Entities recategorized by LLM: 5/12 (41.7%)
#
# Recategorization details:
#    - September 13, 2025                                : Other                → Media/Source
#    - Ritholtz Wealth Management                        : Other                → Company
#    - Chicago                                           : Other                → Media/Source
#    - Zach Cregger                                      : Other                → Media/Source
#    - San Francisco                                     : Other                → Geographic
#
# ✅ Hybrid categorization complete!
#
# ======================================================================
# TEST 4: Pure LLM Categorization (All entities)
# ======================================================================
# ⏱️  Note: This will call LLM for ALL entities (may take 30-60 seconds)...
#
#
# Results (Pure LLM mode):
# ----------------------------------------------------------------------
#  1. 🤖 Exxon Mobil Corporation                     → Company              (conf: 0.90)
#  2. 🤖 September 13, 2025                          → Media/Source         (conf: 0.90)
#  3. 🤖 iPhone                                      → Technology/Product   (conf: 0.90)
#  4. 🤖 Ritholtz Wealth Management                  → Company              (conf: 0.90)
#  5. 🤖 JNJ                                         → Company              (conf: 0.90)
#  6. 🤖 Financial Historical                        → Financial Metric     (conf: 0.90)
#  7. 🤖 Chicago                                     → Media/Source         (conf: 0.90)
#  8. 🤖 2025-09-18                                  → Media/Source         (conf: 0.90)
#  9. 🤖 San Ramon                                   → Industry/Sector      (conf: 0.90)
# 10. 🤖 Zach Cregger                                → Media/Source         (conf: 0.90)
# 11. 🤖 AAPL                                        → Company              (conf: 0.90)
# 12. 🤖 San Francisco                               → Geographic           (conf: 0.90)
#
# 📊 Distribution: {'Company': 4, 'Media/Source': 4, 'Technology/Product': 1, 'Financial Metric': 1, 'Industry/Sector': 1, 'Geographic': 1}
#
# 🤖 LLM calls: 12/12 (100%)
# ⏱️  Time: 2630.1ms (219.2ms per entity)
#
# ======================================================================
# 📊 COMPARISON SUMMARY (Keyword vs Pure LLM)
# ======================================================================
# Entities recategorized by pure LLM: 9/12 (75.0%)
#
# Recategorization details:
#    - September 13, 2025                                : Other                → Media/Source
#    - iPhone                                            : Company              → Technology/Product
#    - Ritholtz Wealth Management                        : Other                → Company
#    - Financial Historical                              : Technology/Product   → Financial Metric
#    - Chicago                                           : Other                → Media/Source
#    - 2025-09-18                                        : Company              → Media/Source
#    - San Ramon                                         : Company              → Industry/Sector
#    - Zach Cregger                                      : Other                → Media/Source
#    - San Francisco                                     : Other                → Geographic
#
# ✅ Pure LLM categorization complete!
#
# ======================================================================
# 🎯 TESTING COMPLETE - 4 Categorization Modes Evaluated
# ======================================================================

# %%
# Purpose: Test relationship categorization with configurable sampling and model selection
# Location: ice_building_workflow.ipynb Cell 12b (after Cell 12)
# Dependencies: graph_categorization.py, relationship_categories.py, LightRAG storage

import json
import time
import sys
import random
import requests
from pathlib import Path
from collections import Counter

# Force reload of graph_categorization module to pick up new functions
import importlib
if 'src.ice_lightrag.graph_categorization' in sys.modules:
    importlib.reload(sys.modules['src.ice_lightrag.graph_categorization'])

# ===== CONFIGURATION: User-editable settings =====
RANDOM_SEED = 42  # Set to None for different relationships each run, or keep 42 for reproducible testing
OLLAMA_MODEL_OVERRIDE = 'qwen2.5:3b'  # Change to use different model (e.g., 'llama3.1:8b', 'qwen3:8b')

# ===== SETUP: Imports with error handling =====
print("=" * 70)
print("🧪 Relationship Categorization Test (4 Modes)")
print("=" * 70)

# Ensure src is in path for notebook context
project_root = Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

try:
    from src.ice_lightrag.graph_categorization import (
        categorize_relationship,
        categorize_relationship_with_confidence,
        categorize_relationship_hybrid,
        categorize_relationship_llm_only
    )
    from src.ice_lightrag.relationship_categories import CATEGORY_DISPLAY_ORDER, extract_relationship_types
    print("✅ Categorization functions imported successfully")
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("   → Ensure previous cells completed successfully")
    print("   → Check that src/ice_lightrag/graph_categorization.py exists\n")
    raise

# Patch module constant for Ollama model selection
import src.ice_lightrag.graph_categorization as graph_cat_module
graph_cat_module.OLLAMA_MODEL = OLLAMA_MODEL_OVERRIDE
print(f"🔧 Ollama model configured: {OLLAMA_MODEL_OVERRIDE}\n")

# ===== HEALTH CHECK: Ollama service availability =====
def check_ollama_service():
    """Check if Ollama service is running and configured model is available"""
    try:
        response = requests.get("http://localhost:11434/api/tags", timeout=2)
        if response.status_code == 200:
            models = response.json().get('models', [])
            # Use exact match to avoid accepting wrong model versions
            model_available = any(m.get('name', '') == OLLAMA_MODEL_OVERRIDE for m in models)
            return True, model_available
        return False, False
    except requests.RequestException:
        return False, False
    except (KeyError, json.JSONDecodeError):
        return True, False

ollama_running, model_available = check_ollama_service()
if ollama_running and model_available:
    print(f"✅ Ollama service running with {OLLAMA_MODEL_OVERRIDE} model")
elif ollama_running:
    print(f"⚠️  Ollama running but {OLLAMA_MODEL_OVERRIDE} not found")
    print(f"   → Install: ollama pull {OLLAMA_MODEL_OVERRIDE}")
else:
    print("⚠️  Ollama not running - TEST 3 & 4 will be skipped")
    print("   → Start Ollama: brew services start ollama (macOS)\n")

# ===== DATA LOADING: Relationships with validation =====
storage_path = Path(ice.config.working_dir) / "vdb_relationships.json"

if not storage_path.exists():
    print(f"❌ Storage file not found: {storage_path}")
    print("   → Run previous cells to build the knowledge graph first\n")
    raise FileNotFoundError(f"LightRAG storage not found at {storage_path}")

with open(storage_path) as f:
    relationships_data = json.load(f)

if not isinstance(relationships_data, dict) or 'data' not in relationships_data:
    print(f"❌ Invalid storage format (expected dict with 'data' key)")
    raise ValueError("Invalid LightRAG storage format - expected {'data': [...]}")

relationships_list = relationships_data.get('data', [])
if not isinstance(relationships_list, list) or len(relationships_list) == 0:
    print(f"❌ No relationships found in storage")
    raise ValueError("No relationships found in LightRAG storage")

print(f"✅ Loaded {len(relationships_list)} relationships from knowledge graph")

# Configurable random sampling
if RANDOM_SEED is not None:
    random.seed(RANDOM_SEED)
    sampling_mode = f"Reproducible (seed={RANDOM_SEED}, same relationships each run)"
else:
    sampling_mode = "Random (different relationships each run)"

test_relationships = random.sample(relationships_list, min(12, len(relationships_list)))
print(f"   Sampling mode: {sampling_mode}")
print(f"   Testing with {len(test_relationships)} relationships")
print(f"   💡 To change: Set RANDOM_SEED = None (line 17) or OLLAMA_MODEL_OVERRIDE (line 18)\n")

# ===== HELPER: Compact result display =====
def display_results(results, title, show_confidence=False, show_llm=False):
    """Display categorization results in compact format"""
    print(f"\n{title}")
    print("-" * 70)

    for i, (name, category, confidence, used_llm) in enumerate(results, 1):
        display_name = name[:40] + "..." if len(name) > 40 else name

        if show_llm and used_llm:
            indicator = "🤖"
        else:
            indicator = "⚡"

        if show_confidence:
            print(f"{i:2d}. {indicator} {display_name:43s} → {category:20s} (conf: {confidence:.2f})")
        else:
            print(f"{i:2d}. {display_name:45s} → {category}")

    category_counts = Counter(cat for _, cat, _, _ in results)
    print(f"\n📊 Distribution: {dict(category_counts)}")

# ===== TEST 1: Keyword-Only Baseline =====
print("\n" + "=" * 70)
print("TEST 1: Keyword-Only Categorization (Baseline)")
print("=" * 70)

start_time = time.time()
keyword_results = []

for relationship in test_relationships:
    content = relationship.get('content', '')
    rel_types = extract_relationship_types(content)
    display_name = rel_types if rel_types else content[:50]
    category = categorize_relationship(content)
    keyword_results.append((display_name, category, 1.0, False))

elapsed = time.time() - start_time
display_results(keyword_results, "Results (Keyword Matching):", show_confidence=False)
print(f"\n⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_relationships):.1f}ms per relationship)")

# ===== TEST 2: Confidence Scoring Analysis =====
print("\n" + "=" * 70)
print("TEST 2: Keyword + Confidence Scoring")
print("=" * 70)

start_time = time.time()
confidence_results = []

for relationship in test_relationships:
    content = relationship.get('content', '')
    rel_types = extract_relationship_types(content)
    display_name = rel_types if rel_types else content[:50]
    category, confidence = categorize_relationship_with_confidence(content)
    confidence_results.append((display_name, category, confidence, False))

elapsed = time.time() - start_time
display_results(confidence_results, "Results (with confidence scores):", show_confidence=True)

low_confidence = [(n, c, conf) for n, c, conf, _ in confidence_results if conf < 0.70]
if low_confidence:
    print(f"\n🔍 Ambiguous relationships (confidence < 0.70): {len(low_confidence)}")
    for name, cat, conf in low_confidence:
        print(f"   - {name[:50]:50s} → {cat:20s} (conf: {conf:.2f})")
else:
    print(f"\n✅ All relationships have high confidence (≥0.70) - no LLM fallback needed")

print(f"\n⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_relationships):.1f}ms per relationship)")

# ===== TEST 3: Hybrid Mode (if Ollama available) =====
if ollama_running and model_available:
    print("\n" + "=" * 70)
    print("TEST 3: Hybrid Categorization (Keyword + LLM Fallback)")
    print("=" * 70)
    print("⏱️  Note: LLM calls may take 5-10 seconds total...\n")

    start_time = time.time()
    hybrid_results = []
    llm_call_count = 0

    for relationship in test_relationships:
        content = relationship.get('content', '')
        rel_types = extract_relationship_types(content)
        display_name = rel_types if rel_types else content[:50]

        keyword_cat, keyword_conf = categorize_relationship_with_confidence(content)

        if keyword_conf >= 0.70:
            category, confidence = keyword_cat, keyword_conf
            used_llm = False
        else:
            category, confidence = categorize_relationship_hybrid(content, confidence_threshold=0.70)
            used_llm = (confidence == 0.90)
            if used_llm:
                llm_call_count += 1

        hybrid_results.append((display_name, category, confidence, used_llm))

    elapsed = time.time() - start_time
    display_results(hybrid_results, "Results (Hybrid mode - keyword + LLM):", show_confidence=True, show_llm=True)

    print(f"\n🤖 LLM calls: {llm_call_count}/{len(test_relationships)} ({100*llm_call_count/len(test_relationships):.1f}%)")
    print(f"⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_relationships):.1f}ms per relationship)")

    # ===== COMPARISON SUMMARY =====
    print("\n" + "=" * 70)
    print("📊 COMPARISON SUMMARY (Keyword vs Hybrid)")
    print("=" * 70)

    changes = 0
    for i in range(len(test_relationships)):
        if keyword_results[i][1] != hybrid_results[i][1]:
            changes += 1

    print(f"Relationships recategorized by LLM: {changes}/{len(test_relationships)} ({100*changes/len(test_relationships):.1f}%)")

    if changes > 0:
        print("\nRecategorization details:")
        for i in range(len(test_relationships)):
            kw_cat = keyword_results[i][1]
            hyb_cat = hybrid_results[i][1]
            if kw_cat != hyb_cat:
                name = keyword_results[i][0][:50]
                print(f"   - {name:50s}: {kw_cat:20s} → {hyb_cat}")

    print(f"\n✅ Hybrid categorization complete!")

else:
    print("\n" + "=" * 70)
    print("⚠️  TEST 3 SKIPPED: Ollama not available")
    print("=" * 70)
    print("To enable hybrid mode:")
    print("   1. Install Ollama: https://ollama.com")
    print(f"   2. Pull model: ollama pull {OLLAMA_MODEL_OVERRIDE}")
    print("   3. Start service: brew services start ollama (macOS)")
    print("   4. Re-run this cell")

# ===== TEST 4: Pure LLM Mode (NEW) =====
if ollama_running and model_available:
    print("\n" + "=" * 70)
    print("TEST 4: Pure LLM Categorization (All relationships)")
    print("=" * 70)
    print("⏱️  Note: This will call LLM for ALL relationships (may take 30-60 seconds)...\n")

    start_time = time.time()
    llm_results = []

    for relationship in test_relationships:
        content = relationship.get('content', '')
        rel_types = extract_relationship_types(content)
        display_name = rel_types if rel_types else content[:50]
        category, confidence = categorize_relationship_llm_only(content)
        llm_results.append((display_name, category, confidence, True))

    elapsed = time.time() - start_time
    display_results(llm_results, "Results (Pure LLM mode):", show_confidence=True, show_llm=True)

    print(f"\n🤖 LLM calls: {len(test_relationships)}/{len(test_relationships)} (100%)")
    print(f"⏱️  Time: {elapsed*1000:.1f}ms ({elapsed*1000/len(test_relationships):.1f}ms per relationship)")

    # Compare keyword vs pure LLM
    llm_changes = sum(1 for i in range(len(test_relationships)) if keyword_results[i][1] != llm_results[i][1])
    
    print("\n" + "=" * 70)
    print("📊 COMPARISON SUMMARY (Keyword vs Pure LLM)")
    print("=" * 70)
    print(f"Relationships recategorized by pure LLM: {llm_changes}/{len(test_relationships)} ({100*llm_changes/len(test_relationships):.1f}%)")
    
    if llm_changes > 0:
        print("\nRecategorization details:")
        for i in range(len(test_relationships)):
            kw_cat = keyword_results[i][1]
            llm_cat = llm_results[i][1]
            if kw_cat != llm_cat:
                name = keyword_results[i][0][:50]
                print(f"   - {name:50s}: {kw_cat:20s} → {llm_cat}")

    print(f"\n✅ Pure LLM categorization complete!")

else:
    print("\n" + "=" * 70)
    print("⚠️  TEST 4 SKIPPED: Ollama not available")
    print("=" * 70)
    print("To enable pure LLM mode:")
    print("   1. Install Ollama: https://ollama.com")
    print(f"   2. Pull model: ollama pull {OLLAMA_MODEL_OVERRIDE}")
    print("   3. Start service: brew services start ollama (macOS)")
    print("   4. Re-run this cell")

print("\n" + "=" * 70)
print("🎯 TESTING COMPLETE - 4 Categorization Modes Evaluated")
print("=" * 70)
# Out:
# ======================================================================
# 🧪 Relationship Categorization Test (4 Modes)
# ======================================================================
# ✅ Categorization functions imported successfully
# 🔧 Ollama model configured: qwen2.5:3b
#
# ✅ Ollama service running with qwen2.5:3b model
# ✅ Loaded 337 relationships from knowledge graph
#    Sampling mode: Reproducible (seed=42, same relationships each run)
#    Testing with 12 relationships
#    💡 To change: Set RANDOM_SEED = None (line 17) or OLLAMA_MODEL_OVERRIDE (line 18)
#
#
# ======================================================================
# TEST 1: Keyword-Only Categorization (Baseline)
# ======================================================================
#
# Results (Keyword Matching):
# ----------------------------------------------------------------------
#  1. analyst recommendation,investment opport...   → Media/Analysis
#  2. future prospects,growth potential             → Other
#  3. financial strategy,investment solicitati...   → Financial
#  4. geographic impact,service area reduction      → Impact/Correlation
#  5. article source,financial news,informatio...   → Financial
#  6. financial results,market performance          → Financial
#  7. partnership,provides product                  → Product/Tech
#  8. news publication,source                       → Media/Analysis
#  9. ancestor,historical lineage                   → Other
# 10. company highlight,stock analysis              → Media/Analysis
# 11. driver,production increase                    → Supply Chain
# 12. author contribution,financial analysis        → Financial
#
# 📊 Distribution: {'Media/Analysis': 3, 'Other': 2, 'Financial': 4, 'Impact/Correlation': 1, 'Product/Tech': 1, 'Supply Chain': 1}
#
# ⏱️  Time: 0.2ms (0.0ms per relationship)
#
# ======================================================================
# TEST 2: Keyword + Confidence Scoring
# ======================================================================
#
# Results (with confidence scores):
# ----------------------------------------------------------------------
#  1. ⚡ analyst recommendation,investment opport... → Media/Analysis       (conf: 0.60)
#  2. ⚡ future prospects,growth potential           → Other                (conf: 0.50)
#  3. ⚡ financial strategy,investment solicitati... → Financial            (conf: 0.95)
#  4. ⚡ geographic impact,service area reduction    → Impact/Correlation   (conf: 0.60)
#  5. ⚡ article source,financial news,informatio... → Financial            (conf: 0.95)
#  6. ⚡ financial results,market performance        → Financial            (conf: 0.95)
#  7. ⚡ partnership,provides product                → Product/Tech         (conf: 0.85)
#  8. ⚡ news publication,source                     → Media/Analysis       (conf: 0.60)
#  9. ⚡ ancestor,historical lineage                 → Other                (conf: 0.50)
# 10. ⚡ company highlight,stock analysis            → Media/Analysis       (conf: 0.60)
# 11. ⚡ driver,production increase                  → Supply Chain         (conf: 0.85)
# 12. ⚡ author contribution,financial analysis      → Financial            (conf: 0.95)
#
# 📊 Distribution: {'Media/Analysis': 3, 'Other': 2, 'Financial': 4, 'Impact/Correlation': 1, 'Product/Tech': 1, 'Supply Chain': 1}
#
# 🔍 Ambiguous relationships (confidence < 0.70): 6
#    - analyst recommendation,investment opportunity      → Media/Analysis       (conf: 0.60)
#    - future prospects,growth potential                  → Other                (conf: 0.50)
#    - geographic impact,service area reduction           → Impact/Correlation   (conf: 0.60)
#    - news publication,source                            → Media/Analysis       (conf: 0.60)
#    - ancestor,historical lineage                        → Other                (conf: 0.50)
#    - company highlight,stock analysis                   → Media/Analysis       (conf: 0.60)
#
# ⏱️  Time: 0.2ms (0.0ms per relationship)
#
# ======================================================================
# TEST 3: Hybrid Categorization (Keyword + LLM Fallback)
# ======================================================================
# ⏱️  Note: LLM calls may take 5-10 seconds total...
#
#
# Results (Hybrid mode - keyword + LLM):
# ----------------------------------------------------------------------
#  1. 🤖 analyst recommendation,investment opport... → Market               (conf: 0.90)
#  2. 🤖 future prospects,growth potential           → Product/Tech         (conf: 0.90)
#  3. ⚡ financial strategy,investment solicitati... → Financial            (conf: 0.95)
#  4. 🤖 geographic impact,service area reduction    → Impact/Correlation   (conf: 0.90)
#  5. ⚡ article source,financial news,informatio... → Financial            (conf: 0.95)
#  6. ⚡ financial results,market performance        → Financial            (conf: 0.95)
#  7. ⚡ partnership,provides product                → Product/Tech         (conf: 0.85)
#  8. 🤖 news publication,source                     → Media/Analysis       (conf: 0.90)
#  9. 🤖 ancestor,historical lineage                 → Industry             (conf: 0.90)
# 10. 🤖 company highlight,stock analysis            → Media/Analysis       (conf: 0.90)
# 11. ⚡ driver,production increase                  → Supply Chain         (conf: 0.85)
# 12. ⚡ author contribution,financial analysis      → Financial            (conf: 0.95)
#
# 📊 Distribution: {'Market': 1, 'Product/Tech': 2, 'Financial': 4, 'Impact/Correlation': 1, 'Media/Analysis': 2, 'Industry': 1, 'Supply Chain': 1}
#
# 🤖 LLM calls: 6/12 (50.0%)
# ⏱️  Time: 1319.3ms (109.9ms per relationship)
#
# ======================================================================
# 📊 COMPARISON SUMMARY (Keyword vs Hybrid)
# ======================================================================
# Relationships recategorized by LLM: 3/12 (25.0%)
#
# Recategorization details:
#    - analyst recommendation,investment opportunity     : Media/Analysis       → Market
#    - future prospects,growth potential                 : Other                → Product/Tech
#    - ancestor,historical lineage                       : Other                → Industry
#
# ✅ Hybrid categorization complete!
#
# ======================================================================
# TEST 4: Pure LLM Categorization (All relationships)
# ======================================================================
# ⏱️  Note: This will call LLM for ALL relationships (may take 30-60 seconds)...
#
#
# Results (Pure LLM mode):
# ----------------------------------------------------------------------
#  1. 🤖 analyst recommendation,investment opport... → Financial            (conf: 0.90)
#  2. 🤖 future prospects,growth potential           → Product/Tech         (conf: 0.90)
#  3. 🤖 financial strategy,investment solicitati... → Financial            (conf: 0.90)
#  4. 🤖 geographic impact,service area reduction    → Impact/Correlation   (conf: 0.90)
#  5. 🤖 article source,financial news,informatio... → Media/Analysis       (conf: 0.90)
#  6. 🤖 financial results,market performance        → Market               (conf: 0.90)
#  7. 🤖 partnership,provides product                → Product/Tech         (conf: 0.90)
#  8. 🤖 news publication,source                     → Media/Analysis       (conf: 0.90)
#  9. 🤖 ancestor,historical lineage                 → Industry             (conf: 0.90)
# 10. 🤖 company highlight,stock analysis            → Media/Analysis       (conf: 0.90)
# 11. 🤖 driver,production increase                  → Impact/Correlation   (conf: 0.90)
# 12. 🤖 author contribution,financial analysis      → Media/Analysis       (conf: 0.90)
#
# 📊 Distribution: {'Financial': 2, 'Product/Tech': 2, 'Impact/Correlation': 2, 'Media/Analysis': 4, 'Market': 1, 'Industry': 1}
#
# 🤖 LLM calls: 12/12 (100%)
# ⏱️  Time: 2449.9ms (204.2ms per relationship)
#
# ======================================================================
# 📊 COMPARISON SUMMARY (Keyword vs Pure LLM)
# ======================================================================
# Relationships recategorized by pure LLM: 7/12 (58.3%)
#
# Recategorization details:
#    - analyst recommendation,investment opportunity     : Media/Analysis       → Financial
#    - future prospects,growth potential                 : Other                → Product/Tech
#    - article source,financial news,information source,m: Financial            → Media/Analysis
#    - financial results,market performance              : Financial            → Market
#    - ancestor,historical lineage                       : Other                → Industry
#    - driver,production increase                        : Supply Chain         → Impact/Correlation
#    - author contribution,financial analysis            : Financial            → Media/Analysis
#
# ✅ Pure LLM categorization complete!
#
# ======================================================================
# 🎯 TESTING COMPLETE - 4 Categorization Modes Evaluated
# ======================================================================

# %%
# ## Clear graph storage (COMMENTED BY DEFAULT FOR SAFETY)
# ## Uncomment lines below to clear existing graph:

# ##########################################################
# #                      Clear Graph                       #
# ##########################################################

# # FIX: Reset storage_path to directory (Cell 12 redefined it to file)
# storage_path = Path(ice.config.working_dir)

# if storage_path.exists():
#     print("📊 PRE-DELETION CHECK")
#     check_storage(storage_path)
    
#     shutil.rmtree(storage_path) # Deletes directory + all contents.
#     storage_path.mkdir(parents=True, exist_ok=True) # This re-creates empty directory.
    
#     print("\n✅ POST-DELETION CHECK")
#     check_storage(storage_path)
#     print("\n✅ Graph cleared - will rebuild from scratch")
# else:
#     print("⚠️  Storage path doesn't exist - nothing to clear")
# Out:
# 📊 PRE-DELETION CHECK
#   ⚠️  vdb_entities.json: not found
#   ⚠️  vdb_relationships.json: not found
#   ⚠️  vdb_chunks.json: not found
#   ⚠️  graph_chunk_entity_relation.graphml: not found
#   💾 Total: 0.00 MB
#
# ✅ POST-DELETION CHECK
#   ⚠️  vdb_entities.json: not found
#   ⚠️  vdb_relationships.json: not found
#   ⚠️  vdb_chunks.json: not found
#   ⚠️  graph_chunk_entity_relation.graphml: not found
#   💾 Total: 0.00 MB
#
# ✅ Graph cleared - will rebuild from scratch

# %%
# Portfolio configuration
import pandas as pd

# portfolio_df = pd.read_csv('portfolio_holdings.csv')
portfolio_df = pd.read_csv('portfolio_holdings_folder/portfolio_holdings_diversified_10.csv')

# Basic validation
if portfolio_df.empty:
    raise ValueError("Portfolio CSV is empty")
if 'ticker' not in portfolio_df.columns:
    raise ValueError("CSV must have 'ticker' column")

holdings = portfolio_df['ticker'].tolist()

print(f"🎯 Portfolio Configuration")
print(f"━" * 40)
print(f"Holdings: {', '.join(holdings)} ({len(holdings)} stocks)")
print(f"Sector: {portfolio_df['sector'].iloc[0] if len(portfolio_df) > 0 else 'N/A'}")
print(f"Data Range: 2 years historical (editable in Cell 21)")
print(f"📄 Source: portfolio_holdings.csv")
# Out:
# 🎯 Portfolio Configuration
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Holdings: AAPL, MSFT, NVDA, JNJ, UNH, LLY, JPM, V, XOM, CVX (10 stocks)
# Sector: Technology
# Data Range: 2 years historical (editable in Cell 21)
# 📄 Source: portfolio_holdings.csv

# %% [markdown]
# ## 3. Data Ingestion & Processing

# %%
print("\n📊 Data Source Summary")
print("=" * 50)

# Show ACTUAL metrics if available (not fake percentages)
if ice and ice.core.is_ready():
    storage_stats = ice.core.get_storage_stats()
    print(f"💾 Current Graph Size: {storage_stats['total_storage_bytes'] / (1024*1024):.2f} MB")
    
    # Show real source info if ingestion has run
    if 'ingestion_result' in locals() and 'metrics' in ingestion_result:
        metrics = ingestion_result['metrics']
        if 'data_sources_used' in metrics:
            print(f"✅ Active sources: {', '.join(metrics['data_sources_used'])}")
        print(f"📄 Total documents: {ingestion_result.get('total_documents', 0)}")
    else:
        print("ℹ️ Data source metrics available after ingestion completes")
else:
    print("⚠️ Knowledge graph not ready")
# Out:
# 📊 Data Source Summary
# ==================================================
# 💾 Current Graph Size: 0.00 MB
# ℹ️ Data source metrics available after ingestion completes

# %% [markdown]
# ## 3b. Data Source Contribution Visualization (Week 5)

# %%
ice.core.get_graph_stats()
# Out:
# {'is_ready': True,
#  'storage_indicators': {'all_components_present': False,
#   'chunks_file_size': 0.0,
#   'entities_file_size': 0.0,
#   'relationships_file_size': 0.0,
#   'graph_file_size': 0.0}}

# %%
print("📊 ICE Data Sources Summary (Phase 1 Integration)")
print("=" * 60)
print("\nℹ️  Phase 1 focuses on architecture and data flow patterns.")
print("Actual data ingestion depends on configured API keys.\n")
print("\n1️⃣ API/MCP Sources:")
print("   - NewsAPI: Real-time financial news")
print("   - SEC EDGAR: Regulatory filings (10-K, 10-Q, 8-K)")
print("   - Alpha Vantage: Market data")
print("\n2️⃣ Email Pipeline (Phase 1 Enhanced Documents):")
print("   - Broker research with BUY/SELL signals")
print("   - Enhanced documents: [TICKER:NVDA|confidence:0.95]")
print("   - See detailed demo: imap_email_ingestion_pipeline/investment_email_extractor_simple.ipynb")
print("\n3️⃣ SEC Filings:")
print("   - Management commentary and financial statements")
print("   - Integrated via SEC EDGAR connector")
print("\n💡 All sources → Single LightRAG knowledge graph via ice_simplified.py")
# Out:
# 📊 ICE Data Sources Summary (Phase 1 Integration)
# ============================================================
#
# ℹ️  Phase 1 focuses on architecture and data flow patterns.
# Actual data ingestion depends on configured API keys.
#
#
# 1️⃣ API/MCP Sources:
#    - NewsAPI: Real-time financial news
#    - SEC EDGAR: Regulatory filings (10-K, 10-Q, 8-K)
#    - Alpha Vantage: Market data
#
# 2️⃣ Email Pipeline (Phase 1 Enhanced Documents):
#    - Broker research with BUY/SELL signals
#    - Enhanced documents: [TICKER:NVDA|confidence:0.95]
#    - See detailed demo: imap_email_ingestion_pipeline/investment_email_extractor_simple.ipynb
#
# 3️⃣ SEC Filings:
#    - Management commentary and financial statements
#    - Integrated via SEC EDGAR connector
#
# 💡 All sources → Single LightRAG knowledge graph via ice_simplified.py

# %% [markdown]
# ## 3a. ICE Data Sources Integration (Week 5)
#
# ICE integrates 3 heterogeneous data sources into unified knowledge graph:
#
# **Detailed Demonstrations Available**:
# - 📧 **Email Pipeline**: See `imap_email_ingestion_pipeline/investment_email_extractor_simple.ipynb` (25 cells)
#   - Entity extraction (tickers, ratings, price targets)
#   - BUY/SELL signal extraction with confidence scores
#   - Enhanced document creation with inline metadata
#
# - 📊 **Quick Summary Below**

# %%
# Execute data ingestion
# NOTE: This operation may take several minutes. If it hangs, restart kernel.
print(f"\n📥 Fetching Portfolio Data")
print(f"━" * 50)

if not (ice and ice.is_ready()):
    raise RuntimeError("ICE system not ready for data ingestion")

# Fetch historical data (1 year for faster processing - adjust years parameter as needed)
print(f"🔄 Fetching data for {len(holdings)} holdings...")
ingestion_result = ice.ingest_historical_data(holdings, years=1) # parameter

# Display results
print(f"\n📊 Ingestion Results:")
print(f"  Status: {ingestion_result['status']}")
print(f"  Holdings: {len(ingestion_result['holdings_processed'])}/{len(holdings)}")
print(f"  Documents: {ingestion_result['total_documents']}")

# Show successful holdings
if ingestion_result['holdings_processed']:
    print(f"  ✅ Successful: {', '.join(ingestion_result['holdings_processed'])}")

# Show metrics
if 'metrics' in ingestion_result:
    print(f"\n⏱️  Processing Time: {ingestion_result['metrics']['processing_time']:.2f}s")
    if 'data_sources_used' in ingestion_result['metrics']:
        print(f"  Data Sources: {', '.join(ingestion_result['metrics']['data_sources_used'])}")
    
    # Display investment signals from Phase 2.6.1 EntityExtractor
    if 'investment_signals' in ingestion_result['metrics']:
        signals = ingestion_result['metrics']['investment_signals']
        print(f"\n📧 Investment Signals Captured:")
        print(f"  Broker emails: {signals['email_count']}")
        print(f"  Tickers covered: {signals['tickers_covered']}")
        print(f"  BUY ratings: {signals['buy_ratings']}")
        print(f"  SELL ratings: {signals['sell_ratings']}")
        print(f"  Avg confidence: {signals['avg_confidence']:.2f}")

# Show failures if any
if ingestion_result.get('failed_holdings'):
    print(f"\n❌ Failed Holdings:")
    for failure in ingestion_result['failed_holdings']:
        print(f"  {failure['symbol']}: {failure['error']}")
# Out:
# INFO:updated_architectures.implementation.ice_simplified:Starting historical data ingestion for 10 holdings (1 years)
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for AAPL
# 📥 Fetching Portfolio Data
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🔄 Fetching data for 10 holdings...
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for AAPL from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for AAPL from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for AAPL
# INFO:src.ice_lightrag.model_provider:✅ Using OpenAI provider (gpt-4o-mini)
# INFO: [_] Created new empty graph fiel: ice_lightrag/storage/graph_chunk_entity_relation.graphml
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': 'ice_lightrag/storage/vdb_entities.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': 'ice_lightrag/storage/vdb_relationships.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': 'ice_lightrag/storage/vdb_chunks.json'} 0 data
# INFO: [_] Process 40630 KV load full_docs with 0 records
# INFO: [_] Process 40630 KV load text_chunks with 0 records
# INFO: [_] Process 40630 KV load full_entities with 0 records
# INFO: [_] Process 40630 KV load full_relations with 0 records
# INFO: [_] Process 40630 KV load llm_response_cache with 0 records
# INFO: [_] Process 40630 doc status load doc_status with 0 records
# INFO:src.ice_lightrag.ice_rag_fixed:✅ Pipeline status initialized successfully
# INFO:src.ice_lightrag.ice_rag_fixed:✅ JupyterICERAG initialized successfully
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-4169ddd7ab6265507e2cfad7bfa0fbff
# INFO: Embedding func: 8 new workers initialized  (Timeouts: Func: 30s, Worker: 60s, Health Check: 75s)
# INFO: LLM func: 4 new workers initialized  (Timeouts: Func: 180s, Worker: 360s, Health Check: 375s)
# INFO:  == LLM cache == saving: default:extract:69ad100a27fc37ca7db25eff89331881
# INFO:  == LLM cache == saving: default:extract:fc9d816efa5abcb1b9eb68ba1f7e02e1
# INFO: Chunk 1 of 1 extracted 26 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 26 entities from doc-4169ddd7ab6265507e2cfad7bfa0fbff (async: 8)
# INFO: Merged: `Apple Inc` | 0+1
# INFO: Merged: `USA` | 0+1
# INFO: Merged: `NASDAQ` | 0+1
# INFO: Merged: `TECHNOLOGY` | 0+1
# INFO: Merged: `CONSUMER ELECTRONICS` | 0+1
# INFO: Merged: `Big Five` | 0+1
# INFO: Merged: `iPhone` | 0+1
# INFO: Merged: `iPad` | 0+1
# INFO: Merged: `Mac` | 0+1
# INFO: Merged: `274.5 Billion` | 0+1
# INFO: Merged: `Market Capitalization` | 0+1
# INFO: Merged: `Shares Outstanding` | 0+1
# INFO: Merged: `PE Ratio` | 0+1
# INFO: Merged: `PEG Ratio` | 0+1
# INFO: Merged: `Dividend Per Share` | 0+1
# INFO: Merged: `Dividend Yield` | 0+1
# INFO: Merged: `EPS` | 0+1
# INFO: Merged: `Revenue Per Share` | 0+1
# INFO: Merged: `Profit Margin` | 0+1
# INFO: Merged: `Operating Margin` | 0+1
# INFO: Merged: `Return on Assets` | 0+1
# INFO: Merged: `Return on Equity` | 0+1
# INFO: Merged: `52 Week High` | 0+1
# INFO: Merged: `52 Week Low` | 0+1
# INFO: Merged: `50 Day Moving Average` | 0+1
# INFO: Merged: `200 Day Moving Average` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-4169ddd7ab6265507e2cfad7bfa0fbff (async: 8)
# INFO: Merged: `Apple Inc`~`USA` | 0+1
# INFO: Merged: `Apple Inc`~`NASDAQ` | 0+1
# INFO: Merged: `Apple Inc`~`Big Five` | 0+1
# INFO: Merged: `Apple Inc`~`iPhone` | 0+1
# INFO: Merged: `Apple Inc`~`iPad` | 0+1
# INFO: Merged: `Apple Inc`~`Mac` | 0+1
# INFO: Merged: `274.5 Billion`~`Apple Inc` | 0+1
# INFO: Phase 3: Updating final 26(26+0) entities and  7 relations from doc-4169ddd7ab6265507e2cfad7bfa0fbff
# INFO: Completed merging: 26 entities, 0 extra entities, 7 relations
# INFO: [_] Writing graph with 26 nodes, 7 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-4753e31331727641533b2d817f410edc
# INFO:  == LLM cache == saving: default:extract:722496f86de345ab18880d1e4cc02eb8
# INFO:  == LLM cache == saving: default:extract:0eb42898dd834279e44c1dd5553b4cdf
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-4753e31331727641533b2d817f410edc (async: 8)
# INFO: Merged: `Apple` | 0+1
# INFO: Merged: `iPhone 17` | 0+1
# INFO: Merged: `Apple Watch` | 0+1
# INFO: Merged: `Mariner Wealth Advisors` | 0+1
# INFO: Merged: `September 19, 2025` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 0+1
# INFO: Merged: `iPhone Air` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-4753e31331727641533b2d817f410edc (async: 8)
# INFO: Merged: `Apple`~`iPhone 17` | 0+1
# INFO: Merged: `Yahoo Entertainment`~`iPhone 17` | 0+1
# INFO: Merged: `Apple`~`Apple Watch` | 0+1
# INFO: Merged: `Apple`~`Mariner Wealth Advisors` | 0+1
# INFO: Merged: `Apple`~`iPhone Air` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  5 relations from doc-4753e31331727641533b2d817f410edc
# INFO: Completed merging: 7 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 33 nodes, 12 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-e1b27284e5130be2f9a937913358966b
# INFO:  == LLM cache == saving: default:extract:872d1a999816bc87c8a24742c06a5aa7
# INFO:  == LLM cache == saving: default:extract:13906545022a2e3f04abfe97bb685ece
# INFO: Chunk 1 of 1 extracted 10 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 10 entities from doc-e1b27284e5130be2f9a937913358966b (async: 8)
# INFO: Merged: `Intel` | 0+1
# INFO: Merged: `Apple` | 1+1
# INFO: Merged: `Nvidia` | 0+1
# INFO: Merged: `US Government` | 0+1
# INFO: Merged: `Financial Investment` | 0+1
# INFO: Merged: `D.A.` | 0+1
# INFO: Merged: `Bloomberg` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 1+1
# INFO: Merged: `2025-09-25` | 0+1
# INFO: Merged: `https://finance.yahoo.com/video/intel-needs-apple-invest-nvidia-193000697.html` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-e1b27284e5130be2f9a937913358966b (async: 8)
# INFO: Merged: `Apple`~`Intel` | 0+1
# INFO: Merged: `Intel`~`Nvidia` | 0+1
# INFO: Merged: `Intel`~`US Government` | 0+1
# INFO: Merged: `Bloomberg`~`Intel` | 0+1
# INFO: Merged: `Intel`~`Yahoo Entertainment` | 0+1
# INFO: Phase 3: Updating final 10(10+0) entities and  5 relations from doc-e1b27284e5130be2f9a937913358966b
# INFO: Completed merging: 10 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 41 nodes, 17 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-7cf48daccc1adf4f4965a1c73a53f76e
# INFO:  == LLM cache == saving: default:extract:4cee05b86c40b8c68eaf3eb6d9c53090
# INFO:  == LLM cache == saving: default:extract:38b4cb252430bca096f36fe7af9dc38c
# INFO: Chunk 1 of 1 extracted 7 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-7cf48daccc1adf4f4965a1c73a53f76e (async: 8)
# INFO: Merged: `Apple Inc.` | 0+1
# INFO: Merged: `iPhone 17` | 1+1
# INFO: Merged: `Reuters` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 2+1
# INFO: Merged: `September 19, 2025` | 1+1
# INFO: Merged: `AAPL` | 0+1
# INFO: Merged: `2025-09-26` | 0+1
# INFO: Phase 2: Processing 4 relations from doc-7cf48daccc1adf4f4965a1c73a53f76e (async: 8)
# INFO: Merged: `Apple Inc.`~`iPhone 17` | 0+1
# INFO: Merged: `2025-09-26`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Apple Inc.`~`Reuters` | 0+1
# INFO: Merged: `AAPL`~`Apple Inc.` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  4 relations from doc-7cf48daccc1adf4f4965a1c73a53f76e
# INFO: Completed merging: 7 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 45 nodes, 21 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-09e14a2ea504f59f65a52262dad97707
# INFO:  == LLM cache == saving: default:extract:38903b44fe4aa3edfa75658191f3e427
# INFO:  == LLM cache == saving: default:extract:d4153262c36c5dfec5cd9e621750a8d9
# INFO: Chunk 1 of 1 extracted 10 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 10 entities from doc-09e14a2ea504f59f65a52262dad97707 (async: 8)
# INFO: Merged: `Nvidia` | 1+1
# INFO: Merged: `Jensen Huang` | 0+1
# INFO: Merged: `Taiwan Semiconductor` | 0+1
# INFO: Merged: `Lip-Bu Tan` | 0+1
# INFO: Merged: `Intel` | 1+1
# INFO: Merged: `TSM Stock` | 0+1
# INFO: Merged: `Press Conference` | 0+1
# INFO: Merged: `Barchart.com` | 0+1
# INFO: Merged: `2025-09-18` | 0+1
# INFO: Merged: `https://www.barchart.com/story/news/34900133/nvidia-ceo-jensen-huang-says-you-cant-overstate-the-magic-that-is-taiwan-semiconductor-but-is-tsm-stock-a-buy-at-new-highs` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-09e14a2ea504f59f65a52262dad97707 (async: 8)
# INFO: Merged: `Nvidia`~`Taiwan Semiconductor` | 0+1
# INFO: Merged: `Jensen Huang`~`Taiwan Semiconductor` | 0+1
# INFO: Merged: `TSM Stock`~`Taiwan Semiconductor` | 0+1
# INFO: Merged: `Intel`~`Jensen Huang` | 0+1
# INFO: Merged: `Jensen Huang`~`Lip-Bu Tan` | 0+1
# INFO: Merged: `Barchart.com`~`Jensen Huang` | 0+1
# INFO: Merged: `Barchart.com`~`Taiwan Semiconductor` | 0+1
# INFO: Phase 3: Updating final 10(10+0) entities and  7 relations from doc-09e14a2ea504f59f65a52262dad97707
# INFO: Completed merging: 10 entities, 0 extra entities, 7 relations
# INFO: [_] Writing graph with 53 nodes, 28 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-d69e29922863a59b3269bfaa995388bf
# INFO:  == LLM cache == saving: default:extract:0bf177701a84eb724f765fa4930f10bd
# INFO:  == LLM cache == saving: default:extract:182d97b71fd9ce9ce9edbcf7bb0e4147
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-d69e29922863a59b3269bfaa995388bf (async: 8)
# INFO: Merged: `Apple` | 2+1
# INFO: Merged: `iPhone 17` | 2+1
# INFO: Merged: `Wall Street` | 0+1
# INFO: Merged: `Justin Sullivan` | 0+1
# INFO: Merged: `Launch Event` | 0+1
# INFO: Merged: `Investopedia` | 0+1
# INFO: Merged: `September 13, 2025` | 0+1
# INFO: Merged: `Thinner Model` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-d69e29922863a59b3269bfaa995388bf (async: 8)
# INFO: Merged: `Apple`~`iPhone 17` | 1+1
# INFO: Merged: `Launch Event`~`iPhone 17` | 0+1
# INFO: Merged: `Apple`~`Investopedia` | 0+1
# INFO: Merged: `Wall Street`~`iPhone 17` | 0+1
# INFO: Merged: `Justin Sullivan`~`Launch Event` | 0+1
# INFO: Merged: `Wall Street`~`analysts` | 0+1
# INFO: Merged: `Apple`~`Thinner Model` | 0+1
# INFO: Phase 3: Updating final 9(8+1) entities and  7 relations from doc-d69e29922863a59b3269bfaa995388bf
# INFO: Completed merging: 8 entities, 1 extra entities, 7 relations
# INFO: [_] Writing graph with 60 nodes, 34 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for AAPL: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for MSFT
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for MSFT from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for MSFT from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for MSFT
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-6c4a042964a2107b5d54bcf4fb86b29e
# INFO:  == LLM cache == saving: default:extract:232fb7e7654b6a350b6b64f571047508
# INFO:  == LLM cache == saving: default:extract:a8836e26bb89c95ac9c8a20aed8d293f
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-6c4a042964a2107b5d54bcf4fb86b29e (async: 8)
# INFO: Merged: `Microsoft Corporation` | 0+1
# INFO: Merged: `USA` | 1+1
# INFO: Merged: `Technology Sector` | 0+1
# INFO: Merged: `Software - Infrastructure` | 0+1
# INFO: Merged: `NASDAQ` | 1+1
# INFO: Merged: `Market Capitalization` | 1+1
# INFO: Merged: `52 Week High` | 1+1
# INFO: Merged: `52 Week Low` | 1+1
# INFO: Phase 2: Processing 7 relations from doc-6c4a042964a2107b5d54bcf4fb86b29e (async: 8)
# INFO: Merged: `Microsoft Corporation`~`USA` | 0+1
# INFO: Merged: `Microsoft Corporation`~`NASDAQ` | 0+1
# INFO: Merged: `Microsoft Corporation`~`Technology Sector` | 0+1
# INFO: Merged: `Microsoft Corporation`~`Software - Infrastructure` | 0+1
# INFO: Merged: `Market Capitalization`~`Microsoft Corporation` | 0+1
# INFO: Merged: `52 Week High`~`Microsoft Corporation` | 0+1
# INFO: Merged: `52 Week Low`~`Microsoft Corporation` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  7 relations from doc-6c4a042964a2107b5d54bcf4fb86b29e
# INFO: Completed merging: 8 entities, 0 extra entities, 7 relations
# INFO: [_] Writing graph with 63 nodes, 41 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-1e93ef679fb3285ab09e6b8a02c5b92e
# INFO:  == LLM cache == saving: default:extract:01a7fcf0f52a93ad05797d6b171b7332
# INFO:  == LLM cache == saving: default:extract:68350353b3bb3da401d539287168aef8
# INFO: Chunk 1 of 1 extracted 12 Ent + 12 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 12 entities from doc-1e93ef679fb3285ab09e6b8a02c5b92e (async: 8)
# INFO: Merged: `NVIDIA` | 0+1
# INFO: Merged: `Microsoft` | 0+1
# INFO: Merged: `IBM` | 0+1
# INFO: Merged: `D-Wave` | 0+1
# INFO: Merged: `IonQ` | 0+1
# INFO: Merged: `Quantum Computing Advancements` | 0+1
# INFO: Merged: `Zacks Analyst Blog` | 0+1
# INFO: Merged: `October 3, 2025` | 0+1
# INFO: Merged: `Chicago` | 0+1
# INFO: Merged: `Zacks.com` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 3+1
# INFO: Merged: `2025-10-03T09:10:00Z` | 0+1
# INFO: Phase 2: Processing 12 relations from doc-1e93ef679fb3285ab09e6b8a02c5b92e (async: 8)
# INFO: Merged: `NVIDIA`~`Zacks Analyst Blog` | 0+1
# INFO: Merged: `Microsoft`~`Zacks Analyst Blog` | 0+1
# INFO: Merged: `NVIDIA`~`Quantum Computing Advancements` | 0+1
# INFO: Merged: `IBM`~`Zacks Analyst Blog` | 0+1
# INFO: Merged: `Microsoft`~`Quantum Computing Advancements` | 0+1
# INFO: Merged: `D-Wave`~`Zacks Analyst Blog` | 0+1
# INFO: Merged: `IBM`~`Quantum Computing Advancements` | 0+1
# INFO: Merged: `IonQ`~`Zacks Analyst Blog` | 0+1
# INFO: Merged: `D-Wave`~`Quantum Computing Advancements` | 0+1
# INFO: Merged: `Zacks Analyst Blog`~`Zacks.com` | 0+1
# INFO: Merged: `IonQ`~`Quantum Computing Advancements` | 0+1
# INFO: Merged: `Yahoo Entertainment`~`Zacks Analyst Blog` | 0+1
# INFO: Phase 3: Updating final 12(12+0) entities and  12 relations from doc-1e93ef679fb3285ab09e6b8a02c5b92e
# INFO: Completed merging: 12 entities, 0 extra entities, 12 relations
# INFO: [_] Writing graph with 74 nodes, 53 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-b86711585a43cfa6574dd8e18660604d
# INFO:  == LLM cache == saving: default:extract:2695b165597afcb38ac742c20bdf6610
# INFO:  == LLM cache == saving: default:extract:87b8ac101d54335d435c9cf6064703e1
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-b86711585a43cfa6574dd8e18660604d (async: 8)
# INFO: Merged: `MSFT` | 0+1
# INFO: Merged: `IBM` | 1+1
# INFO: Merged: `QBTS` | 0+1
# INFO: Merged: `IONQ` | 0+1
# INFO: Merged: `Quantum Computing` | 0+1
# INFO: Merged: `2025` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 4+1
# INFO: Merged: `Error Correction` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-b86711585a43cfa6574dd8e18660604d (async: 8)
# INFO: Merged: `MSFT`~`Quantum Computing` | 0+1
# INFO: Merged: `IBM`~`Quantum Computing` | 0+1
# INFO: Merged: `QBTS`~`Quantum Computing` | 0+1
# INFO: Merged: `IONQ`~`Quantum Computing` | 0+1
# INFO: Merged: `2025`~`Quantum Computing` | 0+1
# INFO: Merged: `Quantum Computing`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Error Correction`~`Quantum Computing` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  7 relations from doc-b86711585a43cfa6574dd8e18660604d
# INFO: Completed merging: 8 entities, 0 extra entities, 7 relations
# INFO: [_] Writing graph with 80 nodes, 60 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-ebbf6254571ac0568e9579c1300e104d
# INFO:  == LLM cache == saving: default:extract:d4498c387ae5667e65b601c6358df033
# INFO:  == LLM cache == saving: default:extract:9d03f21f7b215fae73f6c88af5ca5bc2
# INFO: Chunk 1 of 1 extracted 11 Ent + 8 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 11 entities from doc-ebbf6254571ac0568e9579c1300e104d (async: 8)
# INFO: Merged: `NVDA` | 0+1
# INFO: Merged: `PLTR` | 0+1
# INFO: Merged: `MSFT` | 1+1
# INFO: Merged: `IBM` | 2+1
# INFO: Merged: `FFIV` | 0+1
# INFO: Merged: `Big Data` | 0+1
# INFO: Merged: `AI` | 0+1
# INFO: Merged: `Analytics` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 5+1
# INFO: Merged: `2025-09-15` | 0+1
# INFO: Merged: `https://finance.yahoo.com/news/buy-5-big-data-behemoths-111800377.html` | 0+1
# INFO: Phase 2: Processing 8 relations from doc-ebbf6254571ac0568e9579c1300e104d (async: 8)
# INFO: Merged: `Big Data`~`NVDA` | 0+1
# INFO: Merged: `2025-09-15`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Big Data`~`PLTR` | 0+1
# INFO: Merged: `Big Data`~`MSFT` | 0+1
# INFO: Merged: `Big Data`~`IBM` | 0+1
# INFO: Merged: `Big Data`~`FFIV` | 0+1
# INFO: Merged: `AI`~`Big Data` | 0+1
# INFO: Merged: `Analytics`~`Big Data` | 0+1
# INFO: Phase 3: Updating final 11(11+0) entities and  8 relations from doc-ebbf6254571ac0568e9579c1300e104d
# INFO: Completed merging: 11 entities, 0 extra entities, 8 relations
# INFO: [_] Writing graph with 88 nodes, 68 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-474cb1ea4b8d51bef3426d66857a0b6a
# INFO:  == LLM cache == saving: default:extract:c06c765b074dfa616e01c90ae0af899e
# INFO:  == LLM cache == saving: default:extract:2124e56c3f27f4d1891abfca3d191d90
# INFO: Chunk 1 of 1 extracted 5 Ent + 2 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 5 entities from doc-474cb1ea4b8d51bef3426d66857a0b6a (async: 8)
# INFO: Merged: `Craig Melillo` | 0+1
# INFO: Merged: `AI Overinvestment` | 0+1
# INFO: Merged: `Mbi-deepdives.com` | 0+1
# INFO: Merged: `September 29, 2025` | 0+1
# INFO: Merged: `Reader Response` | 0+1
# INFO: Phase 2: Processing 2 relations from doc-474cb1ea4b8d51bef3426d66857a0b6a (async: 8)
# INFO: Merged: `AI Overinvestment`~`Craig Melillo` | 0+1
# INFO: Merged: `AI Overinvestment`~`Mbi-deepdives.com` | 0+1
# INFO: Phase 3: Updating final 5(5+0) entities and  2 relations from doc-474cb1ea4b8d51bef3426d66857a0b6a
# INFO: Completed merging: 5 entities, 0 extra entities, 2 relations
# INFO: [_] Writing graph with 93 nodes, 70 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-b822c32200603cd701b669558affffe3
# INFO:  == LLM cache == saving: default:extract:a6d31e18f7c7151eab7ce475a04d5af0
# INFO:  == LLM cache == saving: default:extract:cd9ceaaa7d7404209e833fdf6ed8a62f
# INFO: Chunk 1 of 1 extracted 8 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-b822c32200603cd701b669558affffe3 (async: 8)
# INFO: Merged: `Microsoft` | 1+1
# INFO: Merged: `Nebius` | 0+1
# INFO: Merged: `Nvidia AI Chips` | 0+1
# INFO: Merged: `ChatGPT` | 0+1
# INFO: Merged: `Copilot` | 0+1
# INFO: Merged: `October 2, 2025` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 6+1
# INFO: Merged: `2025-10-03` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-b822c32200603cd701b669558affffe3 (async: 8)
# INFO: Merged: `Microsoft`~`Nebius` | 0+1
# INFO: Merged: `Nebius`~`Nvidia AI Chips` | 0+1
# INFO: Merged: `Microsoft`~`Nvidia AI Chips` | 0+1
# INFO: Merged: `ChatGPT`~`Microsoft` | 0+1
# INFO: Merged: `Copilot`~`Microsoft` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  5 relations from doc-b822c32200603cd701b669558affffe3
# INFO: Completed merging: 8 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 99 nodes, 75 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for MSFT: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for NVDA
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for NVDA from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for NVDA from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for NVDA
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-4ac0f66448d2834ea41c6a25980072b5
# INFO:  == LLM cache == saving: default:extract:6cd79e9bc61ea41586d8a9db95a68912
# INFO:  == LLM cache == saving: default:extract:3d1c999eadd5695c2ccd94f6a5bcbc7e
# INFO: Chunk 1 of 1 extracted 18 Ent + 17 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 18 entities from doc-4ac0f66448d2834ea41c6a25980072b5 (async: 8)
# INFO: Merged: `NVIDIA Corporation` | 0+1
# INFO: Merged: `Santa Clara` | 0+1
# INFO: Merged: `Graphics Processing Units (GPUs)` | 0+1
# INFO: Merged: `AI Technologies` | 0+1
# INFO: Merged: `System on a Chip (SoC)` | 0+1
# INFO: Merged: `Market Capitalization` | 2+1
# INFO: Merged: `EPS` | 1+1
# INFO: Merged: `Profit Margin` | 1+1
# INFO: Merged: `Return on Equity` | 1+1
# INFO: Merged: `USA` | 2+1
# INFO: Merged: `Technology` | 0+1
# INFO: Merged: `Semiconductors` | 0+1
# INFO: Merged: `Dividend Per Share` | 1+1
# INFO: Merged: `Dividend Yield` | 1+1
# INFO: Merged: `Revenue Per Share` | 1+1
# INFO: Merged: `Operating Margin` | 1+1
# INFO: Merged: `50 Day Moving Average` | 1+1
# INFO: Merged: `200 Day Moving Average` | 1+1
# INFO: Phase 2: Processing 17 relations from doc-4ac0f66448d2834ea41c6a25980072b5 (async: 8)
# INFO: Merged: `NVIDIA Corporation`~`Santa Clara` | 0+1
# INFO: Merged: `Graphics Processing Units (GPUs)`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `AI Technologies`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`System on a Chip (SoC)` | 0+1
# INFO: Merged: `Market Capitalization`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `EPS`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Profit Margin` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Return on Equity` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`USA` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Technology` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Semiconductors` | 0+1
# INFO: Merged: `Dividend Per Share`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `Dividend Yield`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Revenue Per Share` | 0+1
# INFO: Merged: `NVIDIA Corporation`~`Operating Margin` | 0+1
# INFO: Merged: `50 Day Moving Average`~`NVIDIA Corporation` | 0+1
# INFO: Merged: `200 Day Moving Average`~`NVIDIA Corporation` | 0+1
# INFO: Phase 3: Updating final 18(18+0) entities and  17 relations from doc-4ac0f66448d2834ea41c6a25980072b5
# INFO: Completed merging: 18 entities, 0 extra entities, 17 relations
# INFO: [_] Writing graph with 106 nodes, 92 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-b44ec56b9ae5d4ae05f9444d63f17ff7
# INFO:  == LLM cache == saving: default:extract:98923b935b67c85042fcea764e0976b5
# INFO:  == LLM cache == saving: default:extract:e1401489d340bb4290ad02df73a908fe
# INFO: Chunk 1 of 1 extracted 8 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-b44ec56b9ae5d4ae05f9444d63f17ff7 (async: 8)
# INFO: Merged: `China` | 0+1
# INFO: Merged: `Nvidia` | 2+1
# INFO: Merged: `Rhodium Group` | 0+1
# INFO: Merged: `Reva` | 0+1
# INFO: Merged: `Nvidia Chips` | 0+1
# INFO: Merged: `Trade Talks` | 0+1
# INFO: Merged: `Financial Times` | 0+1
# INFO:  == LLM cache == saving: default:summary:376293eb333ba91a747f0130b6c1b0a9
# INFO: LLMmrg: `Yahoo Entertainment` | 7+1
# INFO: Phase 2: Processing 4 relations from doc-b44ec56b9ae5d4ae05f9444d63f17ff7 (async: 8)
# INFO: Merged: `China`~`Nvidia` | 0+1
# INFO: Merged: `Reva`~`Rhodium Group` | 0+1
# INFO: Merged: `Financial Times`~`Nvidia` | 0+1
# INFO: Merged: `Financial Times`~`Yahoo Entertainment` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  4 relations from doc-b44ec56b9ae5d4ae05f9444d63f17ff7
# INFO: Completed merging: 8 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 112 nodes, 96 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-2045c31615994e0c5b122d0a639ecf19
# INFO:  == LLM cache == saving: default:extract:8abe0bd37619747731a2046a837e23c4
# INFO:  == LLM cache == saving: default:extract:c7fef2e816c5e7227e22aa322ddc9fcf
# INFO: Chunk 1 of 1 extracted 9 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 9 entities from doc-2045c31615994e0c5b122d0a639ecf19 (async: 8)
# INFO: Merged: `Nvidia` | 3+1
# INFO: Merged: `Artificial Intelligence` | 0+1
# INFO: Merged: `Large Language Models` | 0+1
# INFO: Merged: `Big Data Centers` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 1+1
# INFO: Merged: `Financial Historical` | 0+1
# INFO: Merged: `September 22, 2025` | 0+1
# INFO: Merged: `AI Boom` | 0+1
# INFO: Merged: `Chips` | 0+1
# INFO: Phase 2: Processing 4 relations from doc-2045c31615994e0c5b122d0a639ecf19 (async: 8)
# INFO: Merged: `Artificial Intelligence`~`Nvidia` | 0+1
# INFO: Merged: `Financial Historical`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `AI Boom`~`Chips` | 0+1
# INFO: Merged: `Artificial Intelligence`~`Big Data Centers` | 0+1
# INFO: Phase 3: Updating final 9(9+0) entities and  4 relations from doc-2045c31615994e0c5b122d0a639ecf19
# INFO: Completed merging: 9 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 119 nodes, 100 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# WARNING: Ignoring document ID (already exists): doc-e1b27284e5130be2f9a937913358966b (unknown_source)
# WARNING: No new unique documents were found.
# INFO: No documents to process
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-821f4d7be36351d1c17fa3cc2a4a19ea
# INFO:  == LLM cache == saving: default:extract:42c4693d72ef0fd8126ebb210ab5a16b
# INFO:  == LLM cache == saving: default:extract:f18e1724c966640bdac1e26716c73a0a
# INFO: Chunk 1 of 1 extracted 9 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 9 entities from doc-821f4d7be36351d1c17fa3cc2a4a19ea (async: 8)
# INFO: Merged: `Jim Cramer` | 0+1
# INFO: Merged: `Nvidia` | 4+1
# INFO: Merged: `AI Chips` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 2+1
# INFO: Merged: `GuruFocus` | 0+1
# INFO: Merged: `Opening Bid Unfiltered` | 0+1
# INFO: Merged: `Financial Historical` | 1+1
# INFO: Merged: `2025-10-07` | 0+1
# INFO: Merged: `https://finance.yahoo.com/news/jim-cramer-says-nvidias-next-170732588.html` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-821f4d7be36351d1c17fa3cc2a4a19ea (async: 8)
# INFO: Merged: `Jim Cramer`~`Nvidia` | 0+1
# INFO: Merged: `GuruFocus`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Yahoo Entertainment`~`https://finance.yahoo.com/news/jim-cramer-says-nvidias-next-170732588.html` | 0+1
# INFO: Merged: `AI Chips`~`Nvidia` | 0+1
# INFO: Merged: `Jim Cramer`~`Opening Bid Unfiltered` | 0+1
# INFO: Merged: `Financial Historical`~`Jim Cramer` | 0+1
# INFO: Merged: `2025-10-07`~`Nvidia` | 0+1
# INFO: Phase 3: Updating final 9(9+0) entities and  7 relations from doc-821f4d7be36351d1c17fa3cc2a4a19ea
# INFO: Completed merging: 9 entities, 0 extra entities, 7 relations
# INFO: [_] Writing graph with 125 nodes, 107 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# WARNING: Ignoring document ID (already exists): doc-1e93ef679fb3285ab09e6b8a02c5b92e (unknown_source)
# WARNING: No new unique documents were found.
# INFO: No documents to process
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for NVDA: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for JNJ
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for JNJ from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for JNJ from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for JNJ
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-3d66587809a099a751694ecb5f6950c1
# INFO:  == LLM cache == saving: default:extract:5c638124ec74d49df975df7dcb3dee61
# INFO:  == LLM cache == saving: default:extract:736049256c84a6f2a7441bae158302f0
# INFO: Chunk 1 of 1 extracted 25 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 25 entities from doc-3d66587809a099a751694ecb5f6950c1 (async: 8)
# INFO: Merged: `Johnson & Johnson` | 0+1
# INFO: Merged: `JNJ` | 0+1
# INFO: Merged: `USA` | 3+1
# INFO: Merged: `Healthcare` | 0+1
# INFO: Merged: `Drug Manufacturers - General` | 0+1
# INFO: Merged: `Dow Jones Industrial Average` | 0+1
# INFO: Merged: `AAA Credit Rating` | 0+1
# INFO: Merged: `Fortune 500` | 0+1
# INFO: Merged: `Market Capitalization` | 3+1
# INFO: Merged: `Shares Outstanding` | 1+1
# INFO: Merged: `PE Ratio` | 1+1
# INFO: Merged: `PEG Ratio` | 1+1
# INFO: Merged: `Book Value` | 0+1
# INFO: Merged: `Dividend Per Share` | 2+1
# INFO: Merged: `Dividend Yield` | 2+1
# INFO: Merged: `EPS` | 2+1
# INFO: Merged: `Revenue Per Share` | 2+1
# INFO: Merged: `Profit Margin` | 2+1
# INFO: Merged: `Operating Margin` | 2+1
# INFO: Merged: `Return on Assets` | 1+1
# INFO: Merged: `Return on Equity` | 2+1
# INFO: Merged: `52 Week High` | 2+1
# INFO: Merged: `52 Week Low` | 2+1
# INFO: Merged: `50 Day Moving Average` | 2+1
# INFO: Merged: `200 Day Moving Average` | 2+1
# INFO: Phase 2: Processing 4 relations from doc-3d66587809a099a751694ecb5f6950c1 (async: 8)
# INFO: Merged: `Johnson & Johnson`~`USA` | 0+1
# INFO: Merged: `Dow Jones Industrial Average`~`Johnson & Johnson` | 0+1
# INFO: Merged: `Fortune 500`~`Johnson & Johnson` | 0+1
# INFO: Merged: `AAA Credit Rating`~`Johnson & Johnson` | 0+1
# INFO: Phase 3: Updating final 25(25+0) entities and  4 relations from doc-3d66587809a099a751694ecb5f6950c1
# INFO: Completed merging: 25 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 133 nodes, 111 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-d2e442f778c0f5e5823310585a2e2026
# INFO:  == LLM cache == saving: default:extract:92c87fc14000a3b7a249755759ad9695
# INFO:  == LLM cache == saving: default:extract:92951cfa45c6b186a0f2e0973ae0725c
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-d2e442f778c0f5e5823310585a2e2026 (async: 8)
# INFO: Merged: `Johnson & Johnson` | 1+1
# INFO: Merged: `Irvine` | 0+1
# INFO: Merged: `Forbes` | 0+1
# INFO: Merged: `2025` | 1+1
# INFO: Merged: `Shareholder Supremacy` | 0+1
# INFO: Merged: `Stock Performance` | 0+1
# INFO: Merged: `October 17, 2023` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-d2e442f778c0f5e5823310585a2e2026 (async: 8)
# INFO: Merged: `Irvine`~`Johnson & Johnson` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Shareholder Supremacy` | 0+1
# INFO: Merged: `Forbes`~`Johnson & Johnson` | 0+1
# INFO: Merged: `2025`~`Johnson & Johnson` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Stock Performance` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  5 relations from doc-d2e442f778c0f5e5823310585a2e2026
# INFO: Completed merging: 7 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 138 nodes, 116 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-a7818144e0b27d16ac0459e06177b492
# INFO:  == LLM cache == saving: default:extract:52a8dbd9e982820617a48d6e1e95a420
# INFO:  == LLM cache == saving: default:extract:80a60155444729db1700d97f5148a302
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 6 entities from doc-a7818144e0b27d16ac0459e06177b492 (async: 8)
# INFO: Merged: `Josh Brown` | 0+1
# INFO: Merged: `Johnson & Johnson` | 2+1
# INFO: Merged: `Wall Street Analysts` | 0+1
# INFO: Merged: `Ritholtz Wealth Management` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 3+1
# INFO: Merged: `Published Article` | 0+1
# INFO: Phase 2: Processing 4 relations from doc-a7818144e0b27d16ac0459e06177b492 (async: 8)
# INFO: Merged: `Johnson & Johnson`~`Josh Brown` | 0+1
# INFO: Merged: `Published Article`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Josh Brown`~`Ritholtz Wealth Management` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Wall Street Analysts` | 0+1
# INFO: Phase 3: Updating final 6(6+0) entities and  4 relations from doc-a7818144e0b27d16ac0459e06177b492
# INFO: Completed merging: 6 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 142 nodes, 120 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-241196b252d765dd3a85f0f1ebba73c2
# INFO:  == LLM cache == saving: default:extract:ab3e22341733289ad1aa14321ba518cd
# INFO:  == LLM cache == saving: default:extract:3ef5dddfc447c66b066d597f395b36db
# INFO: Chunk 1 of 1 extracted 7 Ent + 3 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-241196b252d765dd3a85f0f1ebba73c2 (async: 8)
# INFO: Merged: `Johnson & Johnson` | 3+1
# INFO: Merged: `Dividend Legacy` | 0+1
# INFO: Merged: `13 Best Consistent Dividend Stocks` | 0+1
# INFO: Merged: `Biztoc.com` | 0+1
# INFO: Merged: `2025-09-16` | 0+1
# INFO: Merged: `Johnson & Johnson (JNJ)` | 0+1
# INFO: Merged: `NYSE:JNJ` | 0+1
# INFO: Phase 2: Processing 3 relations from doc-241196b252d765dd3a85f0f1ebba73c2 (async: 8)
# INFO: Merged: `Dividend Legacy`~`Johnson & Johnson` | 0+1
# INFO: Merged: `13 Best Consistent Dividend Stocks`~`Johnson & Johnson` | 0+1
# INFO: Merged: `Biztoc.com`~`Johnson & Johnson` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  3 relations from doc-241196b252d765dd3a85f0f1ebba73c2
# INFO: Completed merging: 7 entities, 0 extra entities, 3 relations
# INFO: [_] Writing graph with 148 nodes, 123 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-234189042fdc75c3197540070e6011fd
# INFO:  == LLM cache == saving: default:extract:e761acd9aebbc1c36c8b7f27666263f8
# INFO:  == LLM cache == saving: default:extract:069c61ac4efaa46e2d90655c1854200d
# INFO: Chunk 1 of 1 extracted 7 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-234189042fdc75c3197540070e6011fd (async: 8)
# INFO: Merged: `Johnson & Johnson` | 4+1
# INFO: Merged: `Dividend Aristocrat` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 4+1
# INFO: Merged: `Recession Proof Dividend Stocks` | 0+1
# INFO: Merged: `September 29, 2025` | 1+1
# INFO: Merged: `https://finance.yahoo.com/news/johnson-johnson-jnj-dividend-aristocrat-173752151.html` | 0+1
# INFO: Merged: `Johnson & Johnson (NYSE:JNJ)` | 0+1
# INFO: Phase 2: Processing 4 relations from doc-234189042fdc75c3197540070e6011fd (async: 8)
# INFO: Merged: `Dividend Aristocrat`~`Johnson & Johnson` | 0+1
# INFO: Merged: `Johnson & Johnson (NYSE:JNJ)`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Recession Proof Dividend Stocks` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  4 relations from doc-234189042fdc75c3197540070e6011fd
# INFO: Completed merging: 7 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 152 nodes, 127 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-1dce7b201ab089a90aa05b1a2bc09c61
# INFO:  == LLM cache == saving: default:extract:9b2f110ec13e1de78a58ea80e45dff25
# INFO:  == LLM cache == saving: default:extract:e2205c7a54c84e1d8f1e69a418ac631f
# INFO: Chunk 1 of 1 extracted 8 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-1dce7b201ab089a90aa05b1a2bc09c61 (async: 8)
# INFO: Merged: `Johnson & Johnson` | 5+1
# INFO: Merged: `Tremfya` | 0+1
# INFO: Merged: `Ulcerative Colitis` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 5+1
# INFO: Merged: `Pharma Stocks` | 0+1
# INFO: Merged: `Date of Publication` | 0+1
# INFO: Merged: `FDA` | 0+1
# INFO: Merged: `Global Healthcare` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-1dce7b201ab089a90aa05b1a2bc09c61 (async: 8)
# INFO: Merged: `Johnson & Johnson`~`Tremfya` | 0+1
# INFO: Merged: `Tremfya`~`Ulcerative Colitis` | 0+1
# INFO: Merged: `Johnson & Johnson`~`Yahoo Entertainment` | 1+1
# INFO: Merged: `Johnson & Johnson`~`Pharma Stocks` | 0+1
# INFO: Merged: `FDA`~`Tremfya` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  5 relations from doc-1dce7b201ab089a90aa05b1a2bc09c61
# INFO: Completed merging: 8 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 158 nodes, 131 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for JNJ: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for UNH
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for UNH from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for UNH from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for UNH
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-c6339203adf757bccc7a93edb9ab5e7a
# INFO:  == LLM cache == saving: default:extract:6a64a9cab0e5cb93212d476bee048049
# INFO:  == LLM cache == saving: default:extract:ff655ca9d2a9586156a4703282e097d6
# INFO: Chunk 1 of 1 extracted 26 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 26 entities from doc-c6339203adf757bccc7a93edb9ab5e7a (async: 8)
# INFO: Merged: `UnitedHealth Group Incorporated` | 0+1
# INFO: Merged: `Minnetonka` | 0+1
# INFO: Merged: `Healthcare Sector` | 0+1
# INFO: Merged: `UnitedHealthcare` | 0+1
# INFO: Merged: `Digital Health` | 0+1
# INFO: Merged: `Telemedicine` | 0+1
# INFO: Merged: `USD` | 0+1
# INFO: Merged: `NYSE` | 0+1
# INFO: Merged: `Healthcare Plans` | 0+1
# INFO: Merged: `Market Capitalization` | 4+1
# INFO: Merged: `Shares Outstanding` | 2+1
# INFO: Merged: `PE Ratio` | 2+1
# INFO: Merged: `PEG Ratio` | 2+1
# INFO: Merged: `Book Value` | 1+1
# INFO: Merged: `Dividend Per Share` | 3+1
# INFO: Merged: `Dividend Yield` | 3+1
# INFO: Merged: `EPS` | 3+1
# INFO: Merged: `Revenue Per Share` | 3+1
# INFO: Merged: `Profit Margin` | 3+1
# INFO: Merged: `Operating Margin` | 3+1
# INFO: Merged: `Return on Assets` | 2+1
# INFO: Merged: `Return on Equity` | 3+1
# INFO: Merged: `52 Week High` | 3+1
# INFO: Merged: `52 Week Low` | 3+1
# INFO: Merged: `50 Day Moving Average` | 3+1
# INFO: Merged: `200 Day Moving Average` | 3+1
# INFO: Phase 2: Processing 5 relations from doc-c6339203adf757bccc7a93edb9ab5e7a (async: 8)
# INFO: Merged: `Minnetonka`~`UnitedHealth Group Incorporated` | 0+1
# INFO: Merged: `Healthcare Sector`~`UnitedHealth Group Incorporated` | 0+1
# INFO: Merged: `UnitedHealth Group Incorporated`~`UnitedHealthcare` | 0+1
# INFO: Merged: `Digital Health`~`UnitedHealth Group Incorporated` | 0+1
# INFO: Merged: `Telemedicine`~`UnitedHealth Group Incorporated` | 0+1
# INFO: Phase 3: Updating final 26(26+0) entities and  5 relations from doc-c6339203adf757bccc7a93edb9ab5e7a
# INFO: Completed merging: 26 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 167 nodes, 136 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-44a501e55c566d1571de928991eb3526
# INFO:  == LLM cache == saving: default:extract:458c2ebd66909a51c03745bfbc7f4022
# INFO:  == LLM cache == saving: default:extract:6c2d3a466898536f0dea6d58a46b306b
# INFO: Chunk 1 of 1 extracted 9 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 9 entities from doc-44a501e55c566d1571de928991eb3526 (async: 8)
# INFO: Merged: `UnitedHealth` | 0+1
# INFO: Merged: `Medicare Advantage` | 0+1
# INFO: Merged: `UNH` | 0+1
# INFO: Merged: `180,000 beneficiaries` | 0+1
# INFO: Merged: `109 counties` | 0+1
# INFO: Merged: `16 states` | 0+1
# INFO: Merged: `Source: Barchart.com` | 0+1
# INFO: Merged: `Published: 2025-10-06T15:20:51Z` | 0+1
# INFO: Merged: `URL: https://www.barchart.com/story/news/35256984/unitedhealth-is-cutting-medicare-advantage-plans-here-is-where-unh-stock-could-be-headed-next` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-44a501e55c566d1571de928991eb3526 (async: 8)
# INFO: Merged: `Medicare Advantage`~`UnitedHealth` | 0+1
# INFO: Merged: `UNH`~`UnitedHealth` | 0+1
# INFO: Merged: `180,000 beneficiaries`~`Medicare Advantage` | 0+1
# INFO: Merged: `109 counties`~`UnitedHealth` | 0+1
# INFO: Merged: `16 states`~`UnitedHealth` | 0+1
# INFO: Phase 3: Updating final 9(9+0) entities and  5 relations from doc-44a501e55c566d1571de928991eb3526
# INFO: Completed merging: 9 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 176 nodes, 141 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-21c5378ef551aa98ecdb87a803cef82d
# INFO:  == LLM cache == saving: default:extract:a5e84793913dfe40fb4f1b64993f87c2
# INFO:  == LLM cache == saving: default:extract:2d71a809fa59f14c7a8ac5f2853b348b
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-21c5378ef551aa98ecdb87a803cef82d (async: 8)
# INFO: Merged: `Warren Buffett` | 0+1
# INFO: Merged: `Berkshire Hathaway` | 0+1
# INFO: Merged: `UnitedHealth` | 1+1
# INFO: Merged: `5,039,564 Shares` | 0+1
# INFO: Merged: `Insurance Companies` | 0+1
# INFO: Merged: `1977 Shareholder Letter` | 0+1
# INFO: Merged: `Barchart.com` | 1+1
# INFO: Merged: `Q2 2025` | 0+1
# INFO: Phase 2: Processing 7 relations from doc-21c5378ef551aa98ecdb87a803cef82d (async: 8)
# INFO: Merged: `Berkshire Hathaway`~`Warren Buffett` | 0+1
# INFO: Merged: `UnitedHealth`~`Warren Buffett` | 0+1
# ...
# INFO: LLMmrg: `Yahoo Entertainment` | 7+1
# INFO: Phase 2: Processing 5 relations from doc-5d8fd06479c2b10d47484db78550eae0 (async: 8)
# INFO: Merged: `Exxon Mobil Corp`~`Wall Street Analysts` | 0+1
# INFO: Merged: `Q3 Earnings Season`~`Wall Street Analysts` | 0+1
# INFO: Merged: `Exxon Mobil Corp`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `10 Stocks to Watch`~`Exxon Mobil Corp` | 0+1
# INFO: Merged: `10 Stocks to Watch`~`Q3 Earnings Season` | 0+1
# INFO: Phase 3: Updating final 5(5+0) entities and  5 relations from doc-5d8fd06479c2b10d47484db78550eae0
# INFO: Completed merging: 5 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 339 nodes, 297 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-9f64312e917ac3ea2651259dc49799df
# INFO:  == LLM cache == saving: default:extract:c79d6057f8c257a4031afa5b50db45c9
# INFO:  == LLM cache == saving: default:extract:fc851e2cc11dc5e452272046c67284f4
# INFO: Chunk 1 of 1 extracted 9 Ent + 6 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 9 entities from doc-9f64312e917ac3ea2651259dc49799df (async: 8)
# INFO: Merged: `EOG Resources` | 0+1
# INFO: Merged: `ExxonMobil` | 0+1
# INFO: Merged: `Diamondback Energy` | 0+1
# INFO: Merged: `Chevron` | 0+1
# INFO: Merged: `Permian Basin` | 0+1
# INFO: Merged: `U.S. Oil Growth` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 1+1
# INFO: Merged: `Rising Oil Output` | 0+1
# INFO: Merged: `Efficiency Gains` | 0+1
# INFO: Phase 2: Processing 6 relations from doc-9f64312e917ac3ea2651259dc49799df (async: 8)
# INFO: Merged: `EOG Resources`~`Permian Basin` | 0+1
# INFO: Merged: `U.S. Oil Growth`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `ExxonMobil`~`Permian Basin` | 0+1
# INFO: Merged: `Diamondback Energy`~`Permian Basin` | 0+1
# INFO: Merged: `Chevron`~`Permian Basin` | 0+1
# INFO: Merged: `Permian Basin`~`U.S. Oil Growth` | 0+1
# INFO: Phase 3: Updating final 9(9+0) entities and  6 relations from doc-9f64312e917ac3ea2651259dc49799df
# INFO: Completed merging: 9 entities, 0 extra entities, 6 relations
# INFO: [_] Writing graph with 347 nodes, 303 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-7b2d14c1e8c7d544b4fae0b960ac5614
# INFO:  == LLM cache == saving: default:extract:b38dc6e957293e1d8943411e8c90ad9b
# INFO:  == LLM cache == saving: default:extract:7cb69a04f4848476c0e417ccf58d133d
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 6 entities from doc-7b2d14c1e8c7d544b4fae0b960ac5614 (async: 8)
# INFO: Merged: `Exxon Mobil Corporation` | 2+1
# INFO: Merged: `Natural Gas and Oil Dividend Stocks` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 2+1
# INFO: Merged: `Top Dividend Stock` | 0+1
# INFO: Merged: `September 24, 2025` | 0+1
# INFO: Merged: `XOM` | 1+1
# INFO: Phase 2: Processing 4 relations from doc-7b2d14c1e8c7d544b4fae0b960ac5614 (async: 8)
# INFO: Merged: `Exxon Mobil Corporation`~`Natural Gas and Oil Dividend Stocks` | 0+1
# INFO: Merged: `Exxon Mobil Corporation`~`Yahoo Entertainment` | 2+1
# INFO: Merged: `Exxon Mobil Corporation`~`Top Dividend Stock` | 0+1
# INFO: Merged: `Exxon Mobil Corporation`~`XOM` | 1+1
# INFO: Phase 3: Updating final 6(6+0) entities and  4 relations from doc-7b2d14c1e8c7d544b4fae0b960ac5614
# INFO: Completed merging: 6 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 350 nodes, 305 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for XOM: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Fetching 1 years of historical data for CVX
# INFO:updated_architectures.implementation.ice_simplified:Fetched company overview for CVX from Alpha Vantage
# INFO:updated_architectures.implementation.ice_simplified:Fetched 5 news articles for CVX from NewsAPI
# INFO:updated_architectures.implementation.ice_simplified:Fetched 6 total documents for CVX
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-e3603333f9ecd771ab2ab0425ed9870d
# INFO:  == LLM cache == saving: default:extract:aa6f8f1dd1dc3c2677bdc59f48c3fabb
# INFO:  == LLM cache == saving: default:extract:c071971bc9ada8d50709c2c03771c88a
# INFO: Chunk 1 of 1 extracted 16 Ent + 15 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 16 entities from doc-e3603333f9ecd771ab2ab0425ed9870d (async: 8)
# INFO: Merged: `Chevron Corporation` | 0+1
# INFO: Merged: `San Ramon` | 0+1
# INFO: Merged: `USA` | 4+1
# INFO: Merged: `ENERGY` | 1+1
# INFO: Merged: `OIL & GAS INTEGRATED` | 1+1
# INFO: Merged: `Market Capitalization` | 1+1
# INFO: Merged: `Shares Outstanding` | 6+1
# INFO: Merged: `Dividend Per Share` | 6+1
# INFO: Merged: `CVX` | 0+1
# INFO: Merged: `NYSE` | 4+1
# INFO: Merged: `USD` | 1+1
# INFO:  == LLM cache == saving: default:summary:d2d21b677d86f50ecdabf05c9a6d7b28
# INFO: LLMmrg: `Return on Equity` | 7+1
# INFO:  == LLM cache == saving: default:summary:a27ca44b764d8a3714712a26263bea75
# INFO: LLMmrg: `52 Week Low` | 7+1
# INFO:  == LLM cache == saving: default:summary:b5c5609dc351ddfb28843aa3e204026c
# INFO: LLMmrg: `50 Day Moving Average` | 7+1
# INFO:  == LLM cache == saving: default:summary:eda05bf7f7c06a420eaddee9ca9a8f88
# INFO: LLMmrg: `52 Week High` | 7+1
# INFO:  == LLM cache == saving: default:summary:6a52944959817bf4de37deaf2a064a1b
# INFO: LLMmrg: `200 Day Moving Average` | 7+1
# INFO: Phase 2: Processing 15 relations from doc-e3603333f9ecd771ab2ab0425ed9870d (async: 8)
# INFO: Merged: `Chevron Corporation`~`San Ramon` | 0+1
# INFO: Merged: `Chevron Corporation`~`USA` | 0+1
# INFO: Merged: `Chevron Corporation`~`ENERGY` | 0+1
# INFO: Merged: `Chevron Corporation`~`OIL & GAS INTEGRATED` | 0+1
# INFO: Merged: `Chevron Corporation`~`Market Capitalization` | 0+1
# INFO: Merged: `Chevron Corporation`~`Shares Outstanding` | 0+1
# INFO: Merged: `Chevron Corporation`~`Dividend Per Share` | 0+1
# INFO: Merged: `Chevron Corporation`~`Return on Equity` | 0+1
# INFO: Merged: `CVX`~`Chevron Corporation` | 0+1
# INFO: Merged: `Chevron Corporation`~`NYSE` | 0+1
# INFO: Merged: `Chevron Corporation`~`USD` | 0+1
# INFO: Merged: `52 Week High`~`Chevron Corporation` | 0+1
# INFO: Merged: `52 Week Low`~`Chevron Corporation` | 0+1
# INFO: Merged: `50 Day Moving Average`~`Chevron Corporation` | 0+1
# INFO: Merged: `200 Day Moving Average`~`Chevron Corporation` | 0+1
# INFO: Phase 3: Updating final 16(16+0) entities and  15 relations from doc-e3603333f9ecd771ab2ab0425ed9870d
# INFO: Completed merging: 16 entities, 0 extra entities, 15 relations
# INFO: [_] Writing graph with 353 nodes, 320 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-38b62cac18b4311b18d14fcf225ca0d6
# INFO:  == LLM cache == saving: default:extract:6f02fc9f67c3232a1d8359bc8ec81732
# INFO:  == LLM cache == saving: default:extract:7943baff15f0bc4aedfc72ca2942949d
# INFO: Chunk 1 of 1 extracted 8 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 8 entities from doc-38b62cac18b4311b18d14fcf225ca0d6 (async: 8)
# INFO: Merged: `Yahoo Entertainment` | 3+1
# INFO: Merged: `U.S. Stock Indexes` | 0+1
# INFO: Merged: `Government Shutdown` | 0+1
# INFO: Merged: `Dividends` | 0+1
# INFO: Merged: `Market Dynamics` | 0+1
# INFO: Merged: `2025-10-06` | 0+1
# INFO: Merged: `9% Yield` | 0+1
# INFO: Merged: `Federal Reserve` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-38b62cac18b4311b18d14fcf225ca0d6 (async: 8)
# INFO: Merged: `U.S. Stock Indexes`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `9% Yield`~`Dividends` | 0+1
# INFO: Merged: `Government Shutdown`~`U.S. Stock Indexes` | 0+1
# INFO: Merged: `Federal Reserve`~`U.S. Stock Indexes` | 0+1
# INFO: Merged: `Government Shutdown`~`Market Dynamics` | 0+1
# INFO: Phase 3: Updating final 8(8+0) entities and  5 relations from doc-38b62cac18b4311b18d14fcf225ca0d6
# INFO: Completed merging: 8 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 360 nodes, 325 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-671f7d85e8516e06553190ff64f76a99
# INFO:  == LLM cache == saving: default:extract:3070d4289010408e2b348712678c03a3
# INFO:  == LLM cache == saving: default:extract:e1826635994c1aaa54b6006b4e5bd97a
# INFO: Chunk 1 of 1 extracted 5 Ent + 3 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 5 entities from doc-671f7d85e8516e06553190ff64f76a99 (async: 8)
# INFO: Merged: `Chevron Corporation` | 1+1
# INFO: Merged: `Natural Gas and Oil Dividend Stock` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 4+1
# INFO: Merged: `September 24, 2025` | 1+1
# INFO: Merged: `CVX` | 1+1
# INFO: Phase 2: Processing 3 relations from doc-671f7d85e8516e06553190ff64f76a99 (async: 8)
# INFO: Merged: `Chevron Corporation`~`Natural Gas and Oil Dividend Stock` | 0+1
# INFO: Merged: `Chevron Corporation`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `CVX`~`Chevron Corporation` | 1+1
# INFO: Phase 3: Updating final 5(5+0) entities and  3 relations from doc-671f7d85e8516e06553190ff64f76a99
# INFO: Completed merging: 5 entities, 0 extra entities, 3 relations
# INFO: [_] Writing graph with 361 nodes, 327 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-55d6ff805b3832a8ecbd1e1fc89db914
# INFO:  == LLM cache == saving: default:extract:61b75795d28eeac0e810f013dfcbf0c6
# INFO:  == LLM cache == saving: default:extract:20fed170f6d024ae1eb985b15dead6a5
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-55d6ff805b3832a8ecbd1e1fc89db914 (async: 8)
# INFO: Merged: `Chevron Corporation` | 2+1
# INFO: Merged: `Eastern Mediterranean` | 0+1
# INFO: Merged: `Offshore Gas Bid` | 0+1
# INFO: Merged: `Most Undervalued Dow Stocks` | 0+1
# INFO: Merged: `Yahoo Entertainment` | 5+1
# INFO: Merged: `2025-09-28` | 0+1
# INFO: Merged: `Chevron Corporation (NYSE:CVX)` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-55d6ff805b3832a8ecbd1e1fc89db914 (async: 8)
# INFO: Merged: `Chevron Corporation`~`Most Undervalued Dow Stocks` | 0+1
# INFO: Merged: `2025-09-28`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Chevron Corporation`~`Eastern Mediterranean` | 0+1
# INFO: Merged: `Chevron Corporation`~`Offshore Gas Bid` | 0+1
# INFO: Merged: `Chevron Corporation`~`Yahoo Entertainment` | 1+1
# INFO: Phase 3: Updating final 7(7+0) entities and  5 relations from doc-55d6ff805b3832a8ecbd1e1fc89db914
# INFO: Completed merging: 7 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 366 nodes, 331 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-ef66dc664749602c7a4f34a1693adc0c
# INFO:  == LLM cache == saving: default:extract:55006ab6dea9f05882071186936c2b96
# INFO:  == LLM cache == saving: default:extract:80661ed5b971f223e55bb471bb71b269
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 7 entities from doc-ef66dc664749602c7a4f34a1693adc0c (async: 8)
# INFO: Merged: `Chevron Corporation` | 3+1
# INFO: Merged: `LNG Stocks` | 0+1
# INFO: Merged: `Hedge Funds` | 1+1
# INFO: Merged: `Yahoo Entertainment` | 6+1
# INFO: Merged: `2025-10-01` | 0+1
# INFO: Merged: `Investment Strategy` | 0+1
# INFO: Merged: `NYSE:CVX` | 0+1
# INFO: Phase 2: Processing 5 relations from doc-ef66dc664749602c7a4f34a1693adc0c (async: 8)
# INFO: Merged: `Chevron Corporation`~`LNG Stocks` | 0+1
# INFO: Merged: `2025-10-01`~`Yahoo Entertainment` | 0+1
# INFO: Merged: `Chevron Corporation`~`Hedge Funds` | 0+1
# INFO: Merged: `Chevron Corporation`~`Yahoo Entertainment` | 2+1
# INFO: Merged: `Chevron Corporation`~`NYSE:CVX` | 0+1
# INFO: Phase 3: Updating final 7(7+0) entities and  5 relations from doc-ef66dc664749602c7a4f34a1693adc0c
# INFO: Completed merging: 7 entities, 0 extra entities, 5 relations
# INFO: [_] Writing graph with 370 nodes, 335 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-2af065ff2ab98358de51e9790b0bb470
# INFO:  == LLM cache == saving: default:extract:9203f252725ee0e43920c6dff2c6a017
# INFO:  == LLM cache == saving: default:extract:ae183655921cfaf28a7fcb1add9d0358
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 6 entities from doc-2af065ff2ab98358de51e9790b0bb470 (async: 8)
# INFO: Merged: `Chevron Corporation` | 4+1
# INFO: Merged: `Dividend Paying Stocks` | 0+1
# INFO: Merged: `September 21, 2025` | 0+1
# INFO: Merged: `CVX` | 2+1
# INFO: Merged: `Chevron Corporation (NYSE:CVX)` | 1+1
# INFO:  == LLM cache == saving: default:summary:ba9e64a7e7c31881afaf2dd1698cdc8d
# INFO: LLMmrg: `Yahoo Entertainment` | 7+1
# INFO: Phase 2: Processing 4 relations from doc-2af065ff2ab98358de51e9790b0bb470 (async: 8)
# INFO: Merged: `Chevron Corporation`~`Dividend Paying Stocks` | 0+1
# INFO: Merged: `Chevron Corporation (NYSE:CVX)`~`Dividend Paying Stocks` | 0+1
# INFO: Merged: `Chevron Corporation`~`Yahoo Entertainment` | 3+1
# INFO: Merged: `CVX`~`Chevron Corporation` | 2+1
# INFO: Phase 3: Updating final 6(6+0) entities and  4 relations from doc-2af065ff2ab98358de51e9790b0bb470
# INFO: Completed merging: 6 entities, 0 extra entities, 4 relations
# INFO: [_] Writing graph with 372 nodes, 337 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stoped
# INFO:src.ice_core.ice_system_manager:Document added: type=financial_historical, graph_updated=True
# INFO:updated_architectures.implementation.ice_simplified:Batch processing completed: 6 successful, 0 failed
# INFO:updated_architectures.implementation.ice_simplified:✅ Historical data ingested for CVX: 6 documents
# INFO:updated_architectures.implementation.ice_simplified:Historical data ingestion completed: 10/10 successful
# 📊 Ingestion Results:
#   Status: success
#   Holdings: 10/10
#   Documents: 60
#   ✅ Successful: AAPL, MSFT, NVDA, JNJ, UNH, LLY, JPM, V, XOM, CVX
#
# ⏱️  Processing Time: 1321.99s
#   Data Sources: alpha_vantage, newsapi, polygon, finnhub

# %% [markdown]
# ## 4. Knowledge Graph Building Pipeline

# %%
# Knowledge Graph Building - Already completed during ingestion
print(f"\n🧠 Knowledge Graph Building")
print(f"━" * 60)

if not (ice and ice.core.is_ready()):
    raise RuntimeError("LightRAG not ready")

print(f"ℹ️  NOTE: Knowledge graph building happens automatically during data ingestion")
print(f"   The ingestion method (ingest_historical_data) already added documents")
print(f"   to the graph via LightRAG. This cell validates that building succeeded.\n")

# Validate that building succeeded by checking storage
storage_stats = ice.core.get_storage_stats()

if storage_stats['total_storage_bytes'] > 0:
    print(f"✅ KNOWLEDGE GRAPH BUILT SUCCESSFULLY")
    print(f"━" * 40)
    print(f"   📄 Documents processed: {ingestion_result.get('total_documents', 0)}")
    print(f"   💾 Storage size: {storage_stats['total_storage_bytes'] / (1024*1024):.2f} MB")
    
    components_ready = sum(1 for c in storage_stats['components'].values() if c['exists'])
    print(f"   🔗 Components ready: {components_ready}/4")
    
    # Create success result for metrics tracking
    building_result = {
        'status': 'success',
        'total_documents': ingestion_result.get('total_documents', 0),
        'metrics': {
            'building_time': ingestion_result.get('metrics', {}).get('processing_time', 0.0),
            'graph_initialized': True
        }
    }
    
    print(f"\n🎯 Graph Building Process:")
    print(f"   1️⃣ Text Chunking: 1200 tokens (optimal for financial documents)")
    print(f"   2️⃣ Entity Extraction: Companies, metrics, risks, regulations")
    print(f"   3️⃣ Relationship Discovery: Dependencies, impacts, correlations")
    print(f"   4️⃣ Graph Construction: LightRAG optimized structure")
    print(f"   5️⃣ Storage: chunks_vdb, entities_vdb, relationships_vdb, graph")
    
    print(f"\n🚀 System ready for intelligent queries!")
    
else:
    print(f"⚠️ NO GRAPH DATA DETECTED")
    print(f"   Storage size: 0 MB")
    print(f"   Check ingestion results above for errors")
    print(f"   Possible causes:")
    print(f"   - No API keys configured")
    print(f"   - All holdings failed to fetch data")
    print(f"   - Network connectivity issues")
    
    building_result = {
        'status': 'error',
        'message': 'No graph data - check ingestion results'
    }
# Out:
# 🧠 Knowledge Graph Building
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ℹ️  NOTE: Knowledge graph building happens automatically during data ingestion
#    The ingestion method (ingest_historical_data) already added documents
#    to the graph via LightRAG. This cell validates that building succeeded.
#
# ✅ KNOWLEDGE GRAPH BUILT SUCCESSFULLY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#    📄 Documents processed: 60
#    💾 Storage size: 11.29 MB
#    🔗 Components ready: 4/4
#
# 🎯 Graph Building Process:
#    1️⃣ Text Chunking: 1200 tokens (optimal for financial documents)
#    2️⃣ Entity Extraction: Companies, metrics, risks, regulations
#    3️⃣ Relationship Discovery: Dependencies, impacts, correlations
#    4️⃣ Graph Construction: LightRAG optimized structure
#    5️⃣ Storage: chunks_vdb, entities_vdb, relationships_vdb, graph
#
# 🚀 System ready for intelligent queries!

# %% [markdown]
# ## 5. Storage Architecture Validation & Monitoring

# %%
# Comprehensive storage validation and metrics
print(f"\n🔍 Storage Architecture Validation")
print(f"━" * 40)

if not (ice and ice.core.is_ready()):
    raise RuntimeError("Cannot validate storage without initialized system")

# Get detailed storage statistics
storage_stats = ice.core.get_storage_stats()
graph_stats = ice.core.get_graph_stats()

print(f"📦 LightRAG Storage Components Status:")
for component_name, component_info in storage_stats['components'].items():
    status_icon = "✅" if component_info['exists'] else "⚠️"
    size_mb = component_info['size_bytes'] / (1024 * 1024) if component_info['size_bytes'] > 0 else 0
    
    print(f"  {status_icon} {component_name}:")
    print(f"    File: {component_info['file']}")
    print(f"    Purpose: {component_info['description']}")
    print(f"    Size: {size_mb:.2f} MB" if size_mb > 0 else "    Size: Not created yet")

print(f"\n📊 Storage Summary:")
print(f"  Working Directory: {storage_stats['working_dir']}")
print(f"  Total Storage: {storage_stats['total_storage_bytes'] / (1024 * 1024):.2f} MB")
print(f"  System Initialized: {storage_stats['is_initialized']}")

print(f"\n🕸️ Knowledge Graph Status:")
print(f"  Graph Ready: {graph_stats['is_ready']}")
if graph_stats.get('storage_indicators'):
    indicators = graph_stats['storage_indicators']
    print(f"  All Components Present: {indicators['all_components_present']}")
    print(f"  Chunks Storage: {indicators['chunks_file_size']:.2f} MB")
    print(f"  Entity Storage: {indicators['entities_file_size']:.2f} MB")
    print(f"  Relationship Storage: {indicators['relationships_file_size']:.2f} MB")
    print(f"  Graph Structure: {indicators['graph_file_size']:.2f} MB")

# Validation checks
print(f"\n✅ Validation Checks:")
validation_score = 0
max_score = 4

# Check 1: System ready
if storage_stats['is_initialized']:
    print(f"  ✅ System initialization: PASSED")
    validation_score += 1
else:
    print(f"  ❌ System initialization: FAILED")

# Check 2: Storage exists
if storage_stats['storage_exists']:
    print(f"  ✅ Storage directory: PASSED")
    validation_score += 1
else:
    print(f"  ❌ Storage directory: FAILED")

# Check 3: Components created
components_exist = sum(1 for c in storage_stats['components'].values() if c['exists'])
if components_exist > 0:
    print(f"  ✅ Storage components: PASSED ({components_exist}/4 created)")
    validation_score += 1
else:
    print(f"  ❌ Storage components: FAILED (no components created)")

# Check 4: Has storage content
if storage_stats['total_storage_bytes'] > 0:
    print(f"  ✅ Storage content: PASSED")
    validation_score += 1
else:
    print(f"  ❌ Storage content: FAILED (no data stored)")

print(f"\n📊 Validation Score: {validation_score}/{max_score} ({(validation_score/max_score)*100:.0f}%)")

if validation_score == max_score:
    print(f"🎉 All validations passed! Knowledge graph is ready for queries.")
elif validation_score >= max_score * 0.75:
    print(f"✅ Most validations passed. System is functional.")
else:
    print(f"⚠️ Some validations failed. Check configuration and retry building.")
# Out:
# 🔍 Storage Architecture Validation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📦 LightRAG Storage Components Status:
#   ✅ chunks_vdb:
#     File: vdb_chunks.json
#     Purpose: Vector database for document chunks
#     Size: 0.72 MB
#   ✅ entities_vdb:
#     File: vdb_entities.json
#     Purpose: Vector database for extracted entities
#     Size: 4.40 MB
#   ✅ relationships_vdb:
#     File: vdb_relationships.json
#     Purpose: Vector database for entity relationships
#     Size: 4.01 MB
#   ✅ graph:
#     File: graph_chunk_entity_relation.graphml
#     Purpose: NetworkX graph structure
#     Size: 0.32 MB
#
# 📊 Storage Summary:
#   Working Directory: ice_lightrag/storage
#   Total Storage: 11.29 MB
#   System Initialized: True
#
# 🕸️ Knowledge Graph Status:
#   Graph Ready: True
#   All Components Present: True
#   Chunks Storage: 0.72 MB
#   Entity Storage: 4.40 MB
#   Relationship Storage: 4.01 MB
#   Graph Structure: 0.32 MB
#
# ✅ Validation Checks:
#   ✅ System initialization: PASSED
#   ✅ Storage directory: PASSED
#   ✅ Storage components: PASSED (4/4 created)
#   ✅ Storage content: PASSED
#
# 📊 Validation Score: 4/4 (100%)
# 🎉 All validations passed! Knowledge graph is ready for queries.

# %% [markdown]
# ## 6. Building Metrics & Performance Analysis

# %%
# Comprehensive building session metrics
print(f"\n📊 Building Session Metrics & Performance")
print(f"━" * 50)

session_metrics = {
    'holdings_count': len(holdings),
    'total_processing_time': 0.0,
    'documents_processed': 0,
    'building_successful': False
}

# Collect metrics from ingestion and building
if 'ingestion_result' in locals() and ingestion_result:
    if 'metrics' in ingestion_result:
        session_metrics['ingestion_time'] = ingestion_result['metrics'].get('processing_time', 0.0)
    session_metrics['documents_processed'] = ingestion_result.get('total_documents', 0)

if 'building_result' in locals() and building_result:
    if building_result.get('status') == 'success':
        session_metrics['building_successful'] = True
    if 'metrics' in building_result:
        building_time = building_result['metrics'].get('building_time', building_result['metrics'].get('update_time', 0.0))
        session_metrics['building_time'] = building_time

# Calculate total time
if 'pipeline_stats' in locals():
    session_metrics['total_processing_time'] = pipeline_stats.get('processing_time', 0.0)

print(f"🎯 Session Overview:")
print(f"  Holdings Processed: {session_metrics['holdings_count']}")
print(f"  Documents Processed: {session_metrics['documents_processed']}")
print(f"  Building Successful: {session_metrics['building_successful']}")

if session_metrics.get('ingestion_time', 0) > 0:
    print(f"\n⏱️ Performance Metrics:")
    print(f"  Data Ingestion Time: {session_metrics['ingestion_time']:.2f}s")
    if session_metrics.get('building_time', 0) > 0:
        print(f"  Graph Building Time: {session_metrics['building_time']:.2f}s")
        print(f"  Total Processing Time: {session_metrics['ingestion_time'] + session_metrics['building_time']:.2f}s")
    
    print(f"\n📈 Efficiency Analysis:")
    if session_metrics['documents_processed'] > 0:
        docs_per_second = session_metrics['documents_processed'] / session_metrics['ingestion_time']
        print(f"  Processing Rate: {docs_per_second:.2f} documents/second")
    
    holdings_per_second = session_metrics['holdings_count'] / session_metrics['ingestion_time']
    print(f"  Holdings Rate: {holdings_per_second:.2f} holdings/second")

# Architecture efficiency comparison
print(f"\n🏗️ Architecture Efficiency:")
print(f"  ICE Simplified: 2,508 lines of code")
print(f"  Code Reduction: 83% (vs 15,000 line original)")
print(f"  Files Count: 5 core modules")
print(f"  Dependencies: Direct LightRAG wrapper")
print(f"  Token Efficiency: 4,000x better than GraphRAG")

# Success summary
print(f"\n✅ Building Session Summary:")
if session_metrics['building_successful']:
    print(f"  🎉 Knowledge graph building completed successfully")
    print(f"  📊 {session_metrics['documents_processed']} documents processed")
    print(f"  🚀 System ready for intelligent investment queries")
    print(f"  💡 Proceed to ice_query_workflow.ipynb for analysis")
else:
    print(f"  ⚠️ Building completed with warnings or in demo mode")
    print(f"  📋 Review configuration and API settings")
    print(f"  🔧 Consider running with fresh data if issues persist")

print(f"\n🔗 Next Steps:")
print(f"  1. Review building metrics and validate storage")
print(f"  2. Run ice_query_workflow.ipynb for portfolio analysis")
print(f"  3. Test different LightRAG query modes")
print(f"  4. Monitor system performance and optimize as needed")
# Out:
# 📊 Building Session Metrics & Performance
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎯 Session Overview:
#   Holdings Processed: 10
#   Documents Processed: 60
#   Building Successful: True
#
# ⏱️ Performance Metrics:
#   Data Ingestion Time: 1321.99s
#   Graph Building Time: 1321.99s
#   Total Processing Time: 2643.97s
#
# 📈 Efficiency Analysis:
#   Processing Rate: 0.05 documents/second
#   Holdings Rate: 0.01 holdings/second
#
# 🏗️ Architecture Efficiency:
#   ICE Simplified: 2,508 lines of code
#   Code Reduction: 83% (vs 15,000 line original)
#   Files Count: 5 core modules
#   Dependencies: Direct LightRAG wrapper
#   Token Efficiency: 4,000x better than GraphRAG
#
# ✅ Building Session Summary:
#   🎉 Knowledge graph building completed successfully
#   📊 60 documents processed
#   🚀 System ready for intelligent investment queries
#   💡 Proceed to ice_query_workflow.ipynb for analysis
#
# 🔗 Next Steps:
#   1. Review building metrics and validate storage
#   2. Run ice_query_workflow.ipynb for portfolio analysis
#   3. Test different LightRAG query modes
#   4. Monitor system performance and optimize as needed

# %% [markdown]
# ## 📋 Building Workflow Complete
#
# **Summary**: This notebook demonstrated the complete ICE building workflow from data ingestion through knowledge graph construction.
#
# ### Key Achievements
# ✅ **System Initialization**: ICE simplified architecture deployed
# ✅ **Data Ingestion**: Portfolio data fetched and processed
# ✅ **Graph Building**: LightRAG knowledge graph constructed
# ✅ **Storage Validation**: All components verified and metrics tracked
#
# ### Architecture Benefits
# - **83% Code Reduction**: 2,508 lines vs 15,000 original
# - **4,000x Token Efficiency**: vs GraphRAG baseline
# - **Mode Flexibility**: Initial build or incremental updates
# - **Complete Metrics**: Processing time, success rates, storage stats
#
# ### Next Steps
# 1. **Launch Query Workflow**: Open `ice_query_workflow.ipynb`
# 2. **Test Investment Intelligence**: Run portfolio analysis queries
# 3. **Explore Query Modes**: Test all 5 LightRAG modes
# 4. **Monitor Performance**: Track query response times and accuracy
#
# ---
# **Ready for Investment Intelligence Queries** 🚀
