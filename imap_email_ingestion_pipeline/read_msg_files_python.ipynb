# %% [markdown]
# ## Python script to read .msg files.

# %%
if __name__ == "__main__":
    # Check for .msg files in current directory
    import glob
    msg_files = glob.glob("*.msg")

    if msg_files:
        print(f"Found {len(msg_files)} .msg file(s):")
        for msg_file in msg_files:
            print(f"Processing: {msg_file}")
            try:
                read_msg_file(msg_file)
                print("-" * 50)
            except Exception as e:
                print(f"Error processing {msg_file}: {e}")
    else:
        print("No .msg files found in current directory.")
        print("Place .msg files here or update the file path.")
# Out:
# No .msg files found in current directory.
# Place .msg files here or update the file path.
